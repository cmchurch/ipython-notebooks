# %% [markdown]
# ## IMPORTS AND FUNCTION DEFINITIONS (Natural Language Toolkit and Stanford POS Tagger)

# %%
#Christopher M. Church
#PhD Candidate, UC Berkeley, History
#Social Science D-Lab, UC Berkeley

# %%
#IMPORTS AND FUNCTION DEFINITIONS

#NLTK

#imports
import nltk #import the natural language toolkit library
from nltk.stem.snowball import FrenchStemmer #import the French stemming library
from nltk.corpus import stopwords #import stopwords from nltk corpus
import re #import the regular expressions library; will be used to strip punctuation
from collections import Counter #allows for counting the number of occurences in a list

import os #import os module
root_path = "D:\\PhD Research - UC Berkeley\\Research\\DisasterXML" #define a working directory path
os.chdir(root_path) #set the working directory path

#reading in the raw text from the file
def read_raw_file(path):
    '''reads in raw text from a text file using the argument (path), which represents the path/to/file'''
    f = open(path,"r") #open the file located at "path" as a file object (f) that is readonly
    raw = f.read().decode('utf8') # read raw text into a variable (raw) after decoding it from utf8
    f.close() #close the file now that it isn;t being used any longer
    return raw

def get_tokens(raw,encoding='utf8'):
    '''get the nltk tokens from a text'''
    tokens = nltk.word_tokenize(raw) #tokenize the raw UTF-8 text
    return tokens

def get_nltk_text(raw,encoding='utf8'):
    '''create an nltk text using the passed argument (raw) after filtering out the commas'''
    #turn the raw text into an nltk text object
    no_commas = re.sub(r'[.|,|\']',' ', raw) #filter out all the commas, periods, and appostrophes using regex
    tokens = nltk.word_tokenize(no_commas) #generate a list of tokens from the raw text
    text=nltk.Text(tokens,encoding) #create a nltk text from those tokens
    return text

def get_stopswords(type="veronis"):
    '''returns the veronis stopwords in unicode, or if any other value is passed, it returns the default nltk french stopwords'''
    if type=="veronis":
        #VERONIS STOPWORDS
        raw_stopword_list = ["Ap.", "Apr.", "GHz", "MHz", "USD", "a", "afin", "ah", "ai", "aie", "aient", "aies", "ait", "alors", "après", "as", "attendu", "au", "au-delà", "au-devant", "aucun", "aucune", "audit", "auprès", "auquel", "aura", "aurai", "auraient", "aurais", "aurait", "auras", "aurez", "auriez", "aurions", "aurons", "auront", "aussi", "autour", "autre", "autres", "autrui", "aux", "auxdites", "auxdits", "auxquelles", "auxquels", "avaient", "avais", "avait", "avant", "avec", "avez", "aviez", "avions", "avons", "ayant", "ayez", "ayons", "b", "bah", "banco", "ben", "bien", "bé", "c", "c'", "c'est", "c'était", "car", "ce", "ceci", "cela", "celle", "celle-ci", "celle-là", "celles", "celles-ci", "celles-là", "celui", "celui-ci", "celui-là", "celà", "cent", "cents", "cependant", "certain", "certaine", "certaines", "certains", "ces", "cet", "cette", "ceux", "ceux-ci", "ceux-là", "cf.", "cg", "cgr", "chacun", "chacune", "chaque", "chez", "ci", "cinq", "cinquante", "cinquante-cinq", "cinquante-deux", "cinquante-et-un", "cinquante-huit", "cinquante-neuf", "cinquante-quatre", "cinquante-sept", "cinquante-six", "cinquante-trois", "cl", "cm", "cm²", "comme", "contre", "d", "d'", "d'après", "d'un", "d'une", "dans", "de", "depuis", "derrière", "des", "desdites", "desdits", "desquelles", "desquels", "deux", "devant", "devers", "dg", "différentes", "différents", "divers", "diverses", "dix", "dix-huit", "dix-neuf", "dix-sept", "dl", "dm", "donc", "dont", "douze", "du", "dudit", "duquel", "durant", "dès", "déjà", "e", "eh", "elle", "elles", "en", "en-dehors", "encore", "enfin", "entre", "envers", "es", "est", "et", "eu", "eue", "eues", "euh", "eurent", "eus", "eusse", "eussent", "eusses", "eussiez", "eussions", "eut", "eux", "eûmes", "eût", "eûtes", "f", "fait", "fi", "flac", "fors", "furent", "fus", "fusse", "fussent", "fusses", "fussiez", "fussions", "fut", "fûmes", "fût", "fûtes", "g", "gr", "h", "ha", "han", "hein", "hem", "heu", "hg", "hl", "hm", "hm³", "holà", "hop", "hormis", "hors", "huit", "hum", "hé", "i", "ici", "il", "ils", "j", "j'", "j'ai", "j'avais", "j'étais", "jamais", "je", "jusqu'", "jusqu'au", "jusqu'aux", "jusqu'à", "jusque", "k", "kg", "km", "km²", "l", "l'", "l'autre", "l'on", "l'un", "l'une", "la", "laquelle", "le", "lequel", "les", "lesquelles", "lesquels", "leur", "leurs", "lez", "lors", "lorsqu'", "lorsque", "lui", "lès", "m", "m'", "ma", "maint", "mainte", "maintes", "maints", "mais", "malgré", "me", "mes", "mg", "mgr", "mil", "mille", "milliards", "millions", "ml", "mm", "mm²", "moi", "moins", "mon", "moyennant", "mt", "m²", "m³", "même", "mêmes", "n", "n'avait", "n'y", "ne", "neuf", "ni", "non", "nonante", "nonobstant", "nos", "notre", "nous", "nul", "nulle", "nº", "néanmoins", "o", "octante", "oh", "on", "ont", "onze", "or", "ou", "outre", "où", "p", "par", "par-delà", "parbleu", "parce", "parmi", "pas", "passé", "pendant", "personne", "peu", "plus", "plus_d'un", "plus_d'une", "plusieurs", "pour", "pourquoi", "pourtant", "pourvu", "près", "puisqu'", "puisque", "q", "qu", "qu'", "qu'elle", "qu'elles", "qu'il", "qu'ils", "qu'on", "quand", "quant", "quarante", "quarante-cinq", "quarante-deux", "quarante-et-un", "quarante-huit", "quarante-neuf", "quarante-quatre", "quarante-sept", "quarante-six", "quarante-trois", "quatorze", "quatre", "quatre-vingt", "quatre-vingt-cinq", "quatre-vingt-deux", "quatre-vingt-dix", "quatre-vingt-dix-huit", "quatre-vingt-dix-neuf", "quatre-vingt-dix-sept", "quatre-vingt-douze", "quatre-vingt-huit", "quatre-vingt-neuf", "quatre-vingt-onze", "quatre-vingt-quatorze", "quatre-vingt-quatre", "quatre-vingt-quinze", "quatre-vingt-seize", "quatre-vingt-sept", "quatre-vingt-six", "quatre-vingt-treize", "quatre-vingt-trois", "quatre-vingt-un", "quatre-vingt-une", "quatre-vingts", "que", "quel", "quelle", "quelles", "quelqu'", "quelqu'un", "quelqu'une", "quelque", "quelques", "quelques-unes", "quelques-uns", "quels", "qui", "quiconque", "quinze", "quoi", "quoiqu'", "quoique", "r", "revoici", "revoilà", "rien", "s", "s'", "sa", "sans", "sauf", "se", "seize", "selon", "sept", "septante", "sera", "serai", "seraient", "serais", "serait", "seras", "serez", "seriez", "serions", "serons", "seront", "ses", "si", "sinon", "six", "soi", "soient", "sois", "soit", "soixante", "soixante-cinq", "soixante-deux", "soixante-dix", "soixante-dix-huit", "soixante-dix-neuf", "soixante-dix-sept", "soixante-douze", "soixante-et-onze", "soixante-et-un", "soixante-et-une", "soixante-huit", "soixante-neuf", "soixante-quatorze", "soixante-quatre", "soixante-quinze", "soixante-seize", "soixante-sept", "soixante-six", "soixante-treize", "soixante-trois", "sommes", "son", "sont", "sous", "soyez", "soyons", "suis", "suite", "sur", "sus", "t", "t'", "ta", "tacatac", "tandis", "te", "tel", "telle", "telles", "tels", "tes", "toi", "ton", "toujours", "tous", "tout", "toute", "toutefois", "toutes", "treize", "trente", "trente-cinq", "trente-deux", "trente-et-un", "trente-huit", "trente-neuf", "trente-quatre", "trente-sept", "trente-six", "trente-trois", "trois", "très", "tu", "u", "un", "une", "unes", "uns", "v", "vers", "via", "vingt", "vingt-cinq", "vingt-deux", "vingt-huit", "vingt-neuf", "vingt-quatre", "vingt-sept", "vingt-six", "vingt-trois", "vis-à-vis", "voici", "voilà", "vos", "votre", "vous", "w", "x", "y", "z", "zéro", "à", "ç'", "ça", "ès", "étaient", "étais", "était", "étant", "étiez", "étions", "été", "étée", "étées", "étés", "êtes", "être", "ô"]
    else:
        #get French stopwords from the nltk kit
        raw_stopword_list = stopwords.words('french') #create a list of all French stopwords
    stopword_list = [word.decode('utf8') for word in raw_stopword_list] #make to decode the French stopwords as unicode objects rather than ascii
    return stopword_list
    

def filter_stopwords(text,stopword_list):
    '''normalizes the words by turning them all lowercase and then filters out the stopwords'''
    words=[w.lower() for w in text] #normalize the words in the text, making them all lowercase
    #filtering stopwords
    filtered_words = [] #declare an empty list to hold our filtered words
    for word in words: #iterate over all words from the text
        if word not in stopword_list and word.isalpha() and len(word) > 1: #only add words that are not in the French stopwords list, are alphabetic, and are more than 1 character
            filtered_words.append(word) #add word to filter_words list if it meets the above conditions
    #filtered_words.sort() #sort filtered_words list
    return filtered_words
    
def stem_words(words):
    '''stems the word list using the French Stemmer'''
    #stemming words
    stemmed_words = [] #declare an empty list to hold our stemmed words
    stemmer = FrenchStemmer() #create a stemmer object in the FrenchStemmer class
    for word in words:
        stemmed_word=stemmer.stem(word) #stem the word
        stemmed_words.append(stemmed_word) #add it to our stemmed word list
    stemmed_words.sort() #sort the stemmed_words
    return stemmed_words
   
def sort_dictionary(dictionary):
    '''returns a sorted dictionary (as tuples) based on the value of each key'''
    return sorted(dictionary.items(), key=lambda x: x[1], reverse=True)

def normalize_counts(counts):
    total = sum(counts.values())
    return dict((word, float(count)/total) for word,count in counts.items())
        
def print_sorted_dictionary(tuple_dict):
    '''print the results of sort_dictionary'''
    for tup in tuple_dict:
        print unicode(tup[1])[0:10] + '\t\t' + unicode(tup[0])
        
def print_words(words):
    '''clean print the unicode words'''
    for word in words:
        print word
        
#USING STANFORD'S FRENCH POS TAGGER, v.3.2
#http://nlp.stanford.edu/software/tagger.shtml
#note: to get NLTK to find java with the tagger, I had to comment out lines 59 and 85 [config_java(options=self.java_options, verbose=False)] in stanford.py [C:\Anaconda\Lib\site-packages\nltk\tag\stanford.py]
#then I had to set the python path directly
        
import nltk #import the Natural Language Processing Kit
from nltk.tag.stanford import POSTagger #Get the Part of Speech tagger from NLP at Stanford, python module that interacts with Java
nltk.internals.config_java("C:/Program Files/Java/jdk1.7.0_21/bin/java.exe", options='-mx1000m',verbose=False) #set the path to java (note: i had to edit stanford.py and comment conflicting settings on lines 59 and 85

tag_abbreviations = {
                    'A': 'adjective',
                    'Adv': 'adverb',
                    'CC': 'coordinating conjunction',
                    'Cl': 'weak clitic pronoun',
                    'CS': 'subordinating conjunction',
                    'D': 'determiner',
                    'ET': 'foreign word',
                    'I': 'interjection',
                    'NC': 'common noun',
                    'NP': 'proper noun',
                    'P': 'preposition',
                    'PREF': 'prefix',
                    'PRO': 'strong pronoun',
                    'V': 'verb',
                    'PONCT': 'punctuation mark',
                    'N': 'noun'}

def pos_tag(to_tag,model_path = root_path + "\\stanford-postagger-full-2013-06-20\\models\\french.tagger",jar_path = root_path + "\\stanford-postagger-full-2013-06-20\\stanford-postagger.jar"):
    '''tag the tokens with part of speech; to_tag is the tags; model_path is the file path to the stanford POS tagger model; and jar_path to the Stanford POS tagger jar file'''
    pos_tagger = POSTagger(model_path,jar_path,encoding='utf8') #create an object of class POSTagger that is encoded in UTF-8
    tags = pos_tagger.tag(to_tag) #run the tagging algorithm on the tokenized raw text
    return tags

def print_pos_tags(tags):
    '''print all the tags with their part of speech; tag[0] is the word; tag[1] is the Part of Speech'''
    for tag in tags: print tag[1]+'\t',tag[0] 
            
def get_pos_tags(tags,pos='ANY'):
    '''get all the tags with their part of speech; tag[0] is the word; tag[1] is the Part of Speech'''
    pos=pos.upper()
    get_tags = []
    if pos=='ANY':
        print 'Please specify a tag to get' 
    else:
        tag_abbreviations_upper = {k.upper():v for k,v in tag_abbreviations.items()}
        if pos in tag_abbreviations_upper:
            for tag in tags: 
                if tag[1].upper()==pos: get_tags.append(tag[0])
        else:
            print "%s is not a valid search term." %(pos)
    return get_tags
            
def search_pos(tags,search_term,pos):
    '''look for a particular POS word prior to the search term, see what comes after the search term'''
    print "POS\tPREC\t\tS.TERM\t\tSUC\n"
    for i,tag in enumerate(tags):
        if tags[i-1][1].upper()==pos.upper() and tag[0].lower()==search_term.lower():
            print str(i)+'\t'+tags[i-1][0]+"\t" + tag[0] + "\t" + tags[i+1][0]

# %% [markdown]
# ## LOAD THE XML FILES

# %%
#this python file goes through the xml doccuments and prints out the text data for a particular element name

#included libraries
import os #allows for path crawling
from xml.dom import minidom #understands XML DOMs

#variables
xml_path= root_path + "\\SMART1890FireXML" #set the path that we are going to read through
elem_name = "para" #name of the dom element to look for
xmls=[] #open up an empty array into which we will store our XML filenames

#get filenames
for root,dirs,files in os.walk(xml_path): #walk through the filepath and look for xml files, storing them in xmls array
    for file in files:
        if file.endswith('.xml'):
            xmls.append(file)
print "Files Loaded: ",xmls


documents=[] #initialize an empty documents array
all_documents={'tokens':[],'raw':''} #initialize an empty all_documents list

#this turns our list of documents read in from the xml files into a list of nltk documents
#each document has an index (ex. documents[0]), and within each document is a dictionary with the items: newspaper, date, raw,tokens, and 
for xml in xmls: # go through each xml document in our xmls array
    xmldoc = minidom.parse(xml_path + "\\" + xml) #parse the XML doc
    itemlist = xmldoc.getElementsByTagName(elem_name) #get all paragraph (para) elements
    newspaper = xmldoc.getElementsByTagName('newspaper') #get newspaper element
    newspaper_name= newspaper[0].attributes['name'].value #set the newspaper_name to the name attribute of the newspaper element
    date = newspaper[0].attributes['date'].value #set the newspaper date to the date attribute of the newspaper element
    raw = '' #initialize the raw variable
    for item in itemlist:
        raw += ' '.join(t.nodeValue for t in item.childNodes if t.nodeType == t.TEXT_NODE)+' ' # add text from the node's data to the variable raw if the node's data is text, also add whitepsace afte reach para element when appended to the raw text variable
    raw = re.sub(r'\s+', ' ',raw) #remove the excess whitespace from the raw text
    tokens = get_tokens(raw) #get the tokens from the text
    sentences = nltk.sent_tokenize(raw)
    text = get_nltk_text(raw) #create a nltk text from the xml document's raw text
    documents.append({'newspaper':newspaper_name,'date':date,'raw':raw,'tokens':tokens,'text':text,'sentences':sentences}) #add all our elements to the array (documents); each element in the array is a dictionary
    all_documents['tokens'].extend(tokens)
    all_documents['raw']+=raw
    
documents = sorted(documents, key=lambda doc: doc['date'])#sort the array according to a document's date
#to sort by paper name then date, use documents = sorted(documents, key=lambda doc: (doc['newspaper'],doc['date']))
# Out:
# Files Loaded:  ['1890-07-05_les-colonies.xml', '1890-07-08_journal-officiel-de-la-guadeloupe.xml', '1890-07-08_les-antilles.xml', '1890-07-08_les-colonies.xml', '1890-06-21_les-colonies.xml', '1890-06-23_journal-officiel-de-la-guadeloupe.xml', '1890-06-24_journal-officiel-de-la-guadeloupe.xml', '1890-06-25_journal-officiel-de-la-guadeloupe.xml', '1890-06-25_les-antilles.xml', '1890-06-25_les-colonies.xml', '1890-06-25_les-colonies-edition-populaire.xml', '1890-06-27_journal-officiel-de-la-guadeloupe.xml', '1890-06-28_les-antilles.xml', '1890-06-28_les-colonies.xml', '1890-06-30_journal-officiel-de-la-guadeloupe.xml', '1890-07-01_journal-officiel-de-la-guadeloupe.xml', '1890-07-02_les-colonies.xml', '1890-07-04_journal-officiel-de-la-guadeloupe.xml', '1890-07-05_les-antilles.xml']

# %%
# Set variables common to all functions in analysis
french_stopwords = get_stopswords()

# %% [markdown]
# ## ANALYSIS CODE

# %%
#print a sorted dictionary of all stemmed and filtered words for each text
for document in documents:
    filtered_words = filter_stopwords(document['text'],french_stopwords)
    print '\n',document['newspaper'],'\t',document['date'],'\n---------------'
    print_sorted_dictionary(sort_dictionary(Counter(stem_words(filtered_words))))

# %%
#print a count of all adjectives filtered for stopwords and stemmed for each text as well as a count of adjectives for all texts
def stemmed_adjectives(tokens):
     tags = pos_tag(tokens)
     adjectives = get_pos_tags(tags,'a') #get all adjectives from the text
     adj_text = nltk.Text(adjectives,'utf8') #create an nltk text from those adjectives
     filtered_adjectives = filter_stopwords(adj_text,french_stopwords) #filter out stopwwords from the adjectives
     stemmed_adjectives = stem_words(filtered_adjectives) #stem the adjectives to normalize them
     adjective_count = sort_dictionary(Counter(stemmed_adjectives)) #count and sort the adjectives
     print_sorted_dictionary(adjective_count) #print the adjectives
        
for document in documents:
     print '\n',document['newspaper'],' - ',document['date'],'\n-----------------------------'
     print stemmed_adjectives(document['tokens'])
print 'ALL TEXT\n----------\n', stemmed_adjectives(all_documents['tokens'])
# Out:
# Les Colonies  -  1890-06-21
# -----------------------------
# None
# Journal Officiel de la Guadeloupe  -  1890-06-23
# -----------------------------
# 2		présent
# 2		compr
# 1		premi
# 1		terribl
# 1		petit
# 1		sos
# 1		détach
# 1		priv
# 1		télégraph
# 1		sœur
# 1		public
# 1		trist
# 1		municipal
# 1		grand
# 1		épouvant
# 1		général
# 1		plein
# 1		effrai
# 1		administr
# 1		possibl
# 1		occidental
# 1		malheur
# 1		militair
# 1		centralis
# 1		égal
# None
#
# Journal officiel de la Guadeloupe  -  1890-06-24
# -----------------------------
# 2		fraternel
# 2		affreux
# 2		priv
# 1		précieux
# 1		guadeloupemartin
# 1		précédent
# 1		nombreux
# 1		général
# 1		directemenet
# 1		malheur
# 1		famin
# 1		immens
# 1		bon
# 1		grand
# 1		diosésain
# 1		transatlant
# None
#
# Journal officiel de la Guadeloupe  -  1890-06-25
# -----------------------------
# 1		premi
# 1		nécessair
# 1		présent
# 1		nouvel
# 1		prssant
# 1		urgent
# 1		affreux
# 1		famin
# 1		pass
# 1		pareil
# 1		insuffis
# 1		télégramm
# 1		cadavr
# 1		larg
# 1		doulour
# 1		grand
# 1		apprend
# 1		sœur
# 1		nouveau
# 1		alimentair
# 1		nombreux
# 1		méconnaiss
# None
#
# Les Antilles  -  1890-06-25
# -----------------------------
# 9		seul
# 7		bon
# 7		général
# 6		grand
# 5		bel
# 4		premi
# 4		pareil
# 4		cher
# 4		vrai
# 4		géner
# 4		malheur
# 4		supérieur
# 3		doulour
# 3		beau
# 3		vast
# 3		mauv
# 3		pénibl
# 3		fauss
# 3		lugubr
# 3		brul
# 3		humain
# 3		second
# 3		militair
# 2		consider
# 2		principal
# 2		polici
# 2		polit
# 2		matériel
# 2		propr
# 2		civil
# 2		suprêm
# 2		absent
# 2		plein
# 2		lament
# 2		pauvr
# 2		terribl
# 1		nécessair
# 1		acharn
# 1		jeun
# 1		récent
# 1		guadeloupéen
# 1		incendi
# 1		insuffis
# 1		noir
# 1		stupeur
# 1		lourd
# 1		moindr
# 1		innombr
# 1		formid
# 1		sépar
# 1		fauch
# 1		brûl
# 1		fournais
# 1		ami
# 1		nouveau
# 1		républicain
# 1		pût
# 1		haut
# 1		immens
# 1		nobl
# 1		affect
# 1		impossibl
# 1		chapel
# 1		critiqu
# 1		troup
# 1		bas
# 1		simpl
# 1		l
# 1		bless
# 1		serv
# 1		enquarti
# 1		surcri
# 1		regret
# 1		enti
# 1		conditionnel
# 1		profond
# 1		nul
# 1		possibl
# 1		affol
# 1		our
# 1		gross
# 1		sain
# 1		superb
# 1		sœur
# 1		priv
# 1		trouv
# 1		sensibl
# 1		heureux
# 1		ressemblenet
# 1		commercial
# 1		canonad
# 1		rud
# 1		charit
# 1		excess
# 1		amer
# 1		pur
# 1		anormal
# 1		opuent
# 1		impuiss
# 1		silenci
# 1		admir
# 1		entier
# 1		miracul
# 1		sûr
# 1		adroit
# 1		tendr
# 1		effroi
# 1		derni
# 1		sacr
# 1		horribl
# 1		infortun
# 1		vieillard
# 1		distinct
# 1		long
# 1		étrang
# 1		tardiv
# 1		impitoi
# 1		invisibl
# 1		attendr
# 1		magnanim
# 1		digu
# 1		publiqu
# 1		malad
# 1		dign
# 1		destructric
# 1		voisin
# 1		fort
# 1		guadaloupéen
# 1		patriot
# 1		contrari
# 1		solid
# 1		irrépar
# 1		intim
# 1		dem
# 1		ue
# 1		vieil
# 1		volontair
# 1		rad
# 1		somptueux
# 1		infatig
# 1		petit
# 1		longu
# 1		indien
# 1		couvert
# 1		déjàpénitent
# 1		audaci
# 1		noirâtr
# 1		pullul
# 1		immédiat
# 1		originair
# 1		décourag
# 1		couch
# 1		blasphématoir
# 1		poign
# 1		extraordinair
# 1		ordinair
# 1		spirituel
# 1		complet
# 1		brasi
# 1		souverain
# 1		décombr
# 1		épuis
# 1		social
# 1		accompl
# 1		métropolitain
# 1		bibliqu
# 1		héroïqu
# 1		trois
# 1		splendid
# 1		latéral
# 1		nombreux
# 1		bateau
# 1		indompt
# 1		actuel
# 1		inform
# 1		troisiem
# None
#
# Les Colonies  -  1890-06-25
# -----------------------------
# 6		grand
# 5		premi
# 4		nouveau
# 4		malheur
# 3		entier
# 3		effroi
# 3		prochain
# 3		terribl
# 3		petit
# 3		complet
# 3		nombreux
# 2		noirc
# 2		noir
# 2		brûl
# 2		énerg
# 2		ancien
# 2		sinistr
# 2		commercial
# 2		bon
# 2		photograph
# 2		nouvel
# 2		probabl
# 2		seul
# 2		intelligent
# 2		alarm
# 1		dist
# 1		consider
# 1		jeun
# 1		anglais
# 1		incap
# 1		lourd
# 1		moindr
# 1		énorm
# 1		étreint
# 1		doulour
# 1		rich
# 1		industriel
# 1		prodigi
# 1		municipal
# 1		immens
# 1		vaill
# 1		étroit
# 1		exact
# 1		mécan
# 1		administr
# 1		grav
# 1		chimiqu
# 1		constern
# 1		hypothécair
# 1		urgent
# 1		respons
# 1		confort
# 1		colonial
# 1		matériel
# 1		honteux
# 1		prob
# 1		atterr
# 1		bass
# 1		louch
# 1		barbar
# 1		miser
# 1		vrai
# 1		rougeâtr
# 1		central
# 1		affam
# 1		impuiss
# 1		écarlat
# 1		admir
# 1		fréquent
# 1		vraisembl
# 1		radical
# 1		vain
# 1		ferm
# 1		arriv
# 1		semblabl
# 1		derni
# 1		sombr
# 1		funest
# 1		paralyt
# 1		sympath
# 1		feu
# 1		morn
# 1		suiv
# 1		trist
# 1		ram
# 1		invraisembl
# 1		inextinguibl
# 1		malad
# 1		géner
# 1		vulgair
# 1		exceptionnel
# 1		indescriptibl
# 1		absent
# 1		bel
# 1		mauv
# 1		militair
# 1		rigour
# 1		vrais
# 1		pauvr
# 1		malhonnêt
# 1		porteur
# 1		modern
# 1		indien
# 1		incomplet
# 1		faux
# 1		blanch
# 1		télégraph
# 1		sis
# 1		épouvant
# 1		deuxiem
# 1		surexcit
# 1		injust
# 1		sérieux
# 1		sincer
# None
#
# Journal Officiel de la Guadeloupe  -  1890-06-27
# -----------------------------
# 1		haut
# 1		national
# 1		bon
# 1		sympath
# None
#
# Les Antilles  -  1890-06-28
# -----------------------------
# 17		premi
# 7		général
# 4		pareil
# 4		doulour
# 4		faibl
# 4		officiel
# 4		suiv
# 4		malheur
# 4		pauvr
# 4		seul
# 4		nombreux
# 3		plein
# 3		cher
# 3		arriv
# 3		derni
# 3		bel
# 3		possibl
# 3		nouvel
# 3		grand
# 3		simpl
# 2		consider
# 2		publiqu
# 2		guadeloupéen
# 2		incendi
# 2		principal
# 2		innombr
# 2		vain
# 2		municipal
# 2		beau
# 2		haut
# 2		util
# 2		vast
# 2		ancien
# 2		sensibl
# 2		colonial
# 2		larg
# 2		priv
# 2		charit
# 2		insond
# 2		séver
# 2		entier
# 2		honor
# 2		diocésain
# 2		infortun
# 2		désesper
# 2		prochain
# 2		fort
# 2		religi
# 2		inouï
# 2		terribl
# 2		sag
# 2		complet
# 2		unanim
# 1		adminstr
# 1		épouvant
# 1		consult
# 1		violent
# 1		vif
# 1		extraodinair
# 1		rapid
# 1		noir
# 1		activ
# 1		moindr
# 1		rich
# 1		industriel
# 1		immens
# 1		minuti
# 1		usini
# 1		impossibl
# 1		pût
# 1		supplementair
# 1		organ
# 1		fonci
# 1		pan
# 1		sinistr
# 1		étroit
# 1		profond
# 1		fou
# 1		particuli
# 1		cœur
# 1		pet
# 1		sum
# 1		matériel
# 1		poison
# 1		tabernacl
# 1		sœur
# 1		chaleur
# 1		évident
# 1		patr
# 1		led
# 1		provisoir
# 1		mer
# 1		vrai
# 1		français
# 1		croiss
# 1		admir
# 1		bon
# 1		désol
# 1		chrétien
# 1		civil
# 1		sufferer
# 1		inexprim
# 1		semblabl
# 1		effroi
# 1		tranquill
# 1		affreux
# 1		viv
# 1		suppli
# 1		sacr
# 1		savan
# 1		adjoint
# 1		prec
# 1		étrang
# 1		auxhabit
# 1		saint
# 1		petit
# 1		abond
# 1		égal
# 1		palliat
# 1		trist
# 1		impéri
# 1		épiscopal
# 1		appel
# 1		géner
# 1		exceptionnel
# 1		debitor
# 1		patriot
# 1		douleur
# 1		fléaux
# 1		det
# 1		magnif
# 1		intim
# 1		militair
# 1		dem
# 1		caveau
# 1		quêt
# 1		centralis
# 1		spécial
# 1		atten
# 1		présent
# 1		longu
# 1		spacieux
# 1		ravag
# 1		spontan
# 1		vert
# 1		probabl
# 1		larmesqu
# 1		immédiat
# 1		divin
# 1		ému
# 1		vêtu
# 1		obligatoir
# 1		poign
# 1		transatlant
# 1		desecour
# 1		brasi
# 1		bienheur
# 1		xxxi
# 1		effect
# 1		opulent
# 1		secour
# 1		intérieur
# 1		sech
# 1		bref
# 1		ornement
# 1		déchir
# 1		funérair
# 1		occasion
# 1		oppress
# 1		sincer
# None
#
# Les Colonies  -  1890-06-28
# -----------------------------
# 5		général
# 5		grand
# 4		premi
# 4		effroi
# 4		derni
# 3		priv
# 3		doulour
# 3		possibl
# 3		plein
# 3		bel
# 3		mélancol
# 2		noirc
# 2		énorm
# 2		photograph
# 2		ancien
# 2		sinistr
# 2		profond
# 2		gross
# 2		colonial
# 2		désert
# 2		lazul
# 2		approxim
# 2		suiv
# 2		difficil
# 2		fort
# 2		terribl
# 2		nouvel
# 2		seul
# 2		complet
# 2		nombreux
# 2		bref
# 1		commerc
# 1		consider
# 1		discord
# 1		consult
# 1		obscur
# 1		pareil
# 1		just
# 1		anglais
# 1		lourd
# 1		moindr
# 1		inutil
# 1		rich
# 1		local
# 1		brûl
# 1		industriel
# 1		anim
# 1		curieux
# 1		honnêt
# 1		publiqu
# 1		énerg
# 1		press
# 1		net
# 1		vast
# 1		lacrima
# 1		conseilleur
# 1		mécan
# 1		inimagin
# 1		affirm
# 1		transatlant
# 1		chimiqu
# 1		virulent
# 1		viv
# 1		pratiqu
# 1		intérieur
# 1		cabl
# 1		conditionnel
# 1		menac
# 1		émus
# 1		droit
# 1		pass
# 1		confort
# 1		pet
# 1		prec
# 1		larg
# 1		légitim
# 1		public
# 1		franc
# 1		patr
# 1		compris
# 1		mer
# 1		inquiet
# 1		pénibl
# 1		impéri
# 1		vrai
# 1		joyeux
# 1		bon
# 1		civil
# 1		arriv
# 1		semblabl
# 1		moral
# 1		funebr
# 1		sombr
# 1		artifici
# 1		précieux
# 1		long
# 1		dessin
# 1		brui
# 1		prochain
# 1		pitoi
# 1		trist
# 1		infect
# 1		navr
# 1		épouvant
# 1		exceptionnel
# 1		patriot
# 1		mauv
# 1		irrépar
# 1		magnif
# 1		cruel
# 1		ain
# 1		petit
# 1		sag
# 1		longu
# 1		monstreux
# 1		probabl
# 1		sis
# 1		court
# 1		inform
# 1		personnel
# 1		immédiat
# 1		multicolor
# 1		xxxi
# 1		roug
# 1		poign
# 1		nu
# 1		sangl
# 1		vaill
# 1		supérieur
# 1		charm
# 1		étincel
# 1		moyen
# 1		mobili
# 1		superflus
# 1		inconnu
# 1		momentan
# 1		exampl
# 1		rigid
# 1		sincer
# None
#
# Journal Officiel de la Guadeloupe  -  1890-06-30
# -----------------------------
# 2		malheur
# 2		général
# 1		premi
# 1		prosper
# 1		municipal
# 1		publiqu
# 1		petit
# 1		télégraph
# 1		grand
# 1		nouvel
# 1		mort
# 1		appel
# 1		pocel
# 1		dem
# 1		précédent
# 1		efficac
# 1		âgé
# 1		centralis
# 1		sûr
# 1		principal
# None
#
# Journal officiel de la Guadeloupe  -  1890-07-01
# -----------------------------
# 1		deuxiem
# 1		viv
# 1		doulour
# 1		bon
# 1		prêt
# 1		mutuel
# None
#
# Les Colonies  -  1890-07-02
# -----------------------------
# 19		grand
# 15		premi
# 11		général
# 8		bon
# 8		derni
# 7		sinistr
# 7		effroi
# 7		malheur
# 7		nouvel
# 5		nouveau
# 5		entier
# 5		nombreux
# 4		énerg
# 4		ancien
# 4		profond
# 4		colonial
# 4		suiv
# 4		rich
# 4		bel
# 4		terribl
# 4		petit
# 4		noirc
# 4		seul
# 4		possibl
# 4		complet
# 3		priv
# 3		noir
# 3		énorm
# 3		doulour
# 3		plein
# 3		transatlant
# 3		brûl
# 3		pauvr
# 3		admir
# 3		civil
# 3		prochain
# 3		vain
# 3		probabl
# 3		mélancol
# 3		vaill
# 2		nécessair
# 2		commerc
# 2		consider
# 2		incendi
# 2		pareil
# 2		anglais
# 2		lourd
# 2		moindr
# 2		municipal
# 2		immens
# 2		patriot
# 2		vast
# 2		intelligent
# 2		photograph
# 2		prec
# 2		heureux
# 2		pet
# 2		désert
# 2		militair
# 2		lazul
# 2		publiqu
# 2		sincer
# 2		commercial
# 2		impuiss
# 2		approxim
# 2		arriv
# 2		semblabl
# 2		long
# 2		sombr
# 2		sympath
# 2		trist
# 2		difficil
# 2		géner
# 2		indescriptibl
# 2		fort
# 2		vrai
# 2		poign
# 2		supérieur
# 2		alarm
# 1		dist
# 1		jeun
# 1		tourn
# 1		obscur
# 1		invraisembl
# 1		ment
# 1		incap
# 1		formid
# 1		étreint
# 1		desperson
# 1		industriel
# 1		anim
# 1		curieux
# 1		beau
# 1		dan
# 1		suffis
# 1		télégraphi
# 1		étroit
# 1		exact
# 1		mécan
# 1		lacrima
# 1		conseilleur
# 1		inimagin
# 1		administr
# 1		mauv
# 1		grav
# 1		nu
# 1		chimiqu
# 1		réun
# 1		fonci
# 1		courag
# 1		lapopul
# 1		cher
# 1		redout
# 1		cabl
# 1		hypothécair
# 1		conditionnel
# 1		menac
# 1		vulgair
# 1		navr
# 1		pass
# 1		confort
# 1		sub
# 1		matériel
# 1		radical
# 1		honteux
# 1		larg
# 1		propr
# 1		urgent
# 1		import
# 1		net
# 1		prob
# 1		influent
# 1		franc
# 1		patr
# 1		atterr
# 1		bass
# 1		infim
# 1		louch
# 1		excess
# 1		barbar
# 1		pénibl
# 1		respect
# 1		miser
# 1		pur
# 1		français
# 1		c
# 1		central
# 1		affam
# 1		just
# 1		écarlat
# 1		joyeux
# 1		prodigi
# 1		fréquent
# 1		vraisembl
# 1		brigandag
# 1		étincel
# 1		croul
# 1		inutil
# 1		mer
# 1		ferm
# 1		inquiet
# 1		affreux
# 1		viv
# 1		intérieur
# 1		artifici
# 1		facil
# 1		funest
# 1		précieux
# 1		pitoi
# 1		constern
# 1		paralyt
# 1		angoiss
# 1		funebr
# 1		surexcit
# 1		dessin
# 1		impitoi
# 1		feu
# 1		morn
# 1		brui
# 1		dur
# 1		abond
# 1		ram
# 1		infect
# 1		public
# 1		rougeâtr
# 1		inextinguibl
# 1		malad
# 1		part
# 1		rigid
# 1		consult
# 1		exceptionnel
# 1		meilleur
# 1		absent
# 1		fraternel
# 1		effrai
# 1		affirm
# 1		plain
# 1		irrépar
# 1		magnif
# 1		cruel
# 1		ain
# 1		rigour
# 1		néfast
# 1		vrais
# 1		vieil
# 1		fum
# 1		inaccessibl
# 1		spécial
# 1		porteur
# 1		présent
# 1		modern
# 1		sag
# 1		indien
# 1		incomplet
# 1		desusin
# 1		faux
# 1		monstreux
# 1		blanch
# 1		court
# 1		sûr
# 1		momentan
# 1		personnel
# 1		immédiat
# 1		multicolor
# 1		télégraph
# 1		roug
# 1		ouvert
# 1		dévou
# 1		haut
# 1		brasi
# 1		sis
# 1		débat
# 1		émouv
# 1		xxxi
# 1		épouvant
# 1		charm
# 1		secour
# 1		moyen
# 1		respons
# 1		extraordnair
# 1		deuxiem
# 1		mobili
# 1		superflus
# 1		bref
# 1		inconnu
# 1		inform
# 1		exampl
# 1		injust
# 1		sérieux
# 1		troisiem
# 1		efficac
# 1		mortel
# 1		malhonnêt
# None
#
# Les Colonies  -  1890-07-02
# -----------------------------
# 11		général
# 10		premi
# 8		bon
# 7		malheur
# 6		sinistr
# 6		grand
# 5		ivre
# 4		municipal
# 4		effroi
# 4		bel
# 3		incendi
# 3		polit
# 3		derni
# 3		suiv
# 3		présent
# 3		seul
# 2		nécessair
# 2		principal
# 2		anglais
# 2		moindr
# 2		honnêt
# 2		nouveau
# 2		profond
# 2		égal
# 2		miser
# 2		admir
# 2		social
# 2		précis
# 2		civil
# 2		funest
# 2		rich
# 2		publiqu
# 2		troisiem
# 2		écrit
# 2		plein
# 2		lament
# 2		soucieux
# 2		haut
# 2		nombreux
# 2		transatlant
# 1		commerc
# 1		épouvant
# 1		consider
# 1		noirc
# 1		touch
# 1		noir
# 1		incap
# 1		lourd
# 1		électoral
# 1		doulour
# 1		desperson
# 1		haineux
# 1		brûl
# 1		gris
# 1		beau
# 1		dan
# 1		immens
# 1		vaill
# 1		prochin
# 1		énerg
# 1		télégraphi
# 1		impossibl
# 1		alimentair
# 1		officiel
# 1		dévou
# 1		possibl
# 1		nu
# 1		réun
# 1		fonci
# 1		grad
# 1		cher
# 1		ruineux
# 1		droit
# 1		foll
# 1		ouvert
# 1		gross
# 1		particuli
# 1		pet
# 1		colonial
# 1		laid
# 1		propr
# 1		import
# 1		priv
# 1		influent
# 1		impassibl
# 1		heureux
# 1		infim
# 1		encombr
# 1		sûr
# 1		pénibl
# 1		popul
# 1		envieux
# 1		pauvr
# 1		américain
# 1		sympath
# 1		esxcess
# 1		uni
# 1		honor
# 1		vain
# 1		suprêm
# 1		arriv
# 1		affreux
# 1		respect
# 1		facil
# 1		français
# 1		commun
# 1		injuri
# 1		prec
# 1		feu
# 1		prochain
# 1		dur
# 1		abond
# 1		difficil
# 1		inexor
# 1		puiss
# 1		géner
# 1		meilleur
# 1		fort
# 1		absent
# 1		patriot
# 1		irrépar
# 1		militair
# 1		néfast
# 1		centralis
# 1		fum
# 1		inaccessibl
# 1		spécial
# 1		terribl
# 1		sag
# 1		voisin
# 1		exist
# 1		situ
# 1		court
# 1		personnel
# 1		vibr
# 1		extraordinair
# 1		intelligent
# 1		complet
# 1		débat
# 1		assist
# 1		charm
# 1		secour
# 1		effac
# 1		charg
# 1		mobili
# 1		stéril
# 1		momentan
# 1		part
# 1		efficac
# None
#
# Journal officiel de la Guadeloupe  -  1890-07-04
# -----------------------------
# 5		général
# 4		grand
# 3		premi
# 3		profond
# 2		civil
# 2		derni
# 2		rich
# 2		malheur
# 2		bon
# 1		inend
# 1		nécessair
# 1		commerc
# 1		énerg
# 1		terribl
# 1		vain
# 1		excess
# 1		spécial
# 1		effroi
# 1		pauvr
# 1		incendi
# 1		touch
# 1		martiniquais
# 1		télégraphi
# 1		sinistr
# 1		communal
# 1		particuli
# 1		sûr
# 1		anglais
# 1		momentan
# 1		botan
# 1		dur
# 1		popul
# 1		mer
# 1		récent
# 1		harilsd
# 1		haut
# 1		patriot
# 1		préced
# 1		part
# 1		prêt
# 1		secour
# 1		géner
# 1		vaill
# 1		abond
# 1		nouveau
# 1		étendu
# 1		deuxiem
# 1		douleur
# 1		mobili
# 1		nombreux
# 1		télégramm
# 1		auxiliair
# 1		réun
# 1		militair
# 1		admir
# 1		mutuel
# 1		efficac
# 1		ide
# 1		américain
# 1		inaccessibl
# 1		supérieur
# None
#
# Les Colonies  -  1890-07-05
# -----------------------------
# 6		grand
# 5		sinistr
# 5		général
# 5		seul
# 4		nécessair
# 4		doulour
# 4		quelconqu
# 4		malheur
# 4		publiqu
# 3		miser
# 3		derni
# 3		nouvel
# 3		ivre
# 2		premi
# 2		froid
# 2		habituel
# 2		indign
# 2		plein
# 2		redout
# 2		précieux
# 2		prochain
# 2		fort
# 2		élev
# 2		pauvr
# 2		petit
# 2		rar
# 2		pir
# 1		connus
# 1		consider
# 1		lde
# 1		flétriss
# 1		récent
# 1		incendi
# 1		odieux
# 1		pareil
# 1		intéress
# 1		vindiqu
# 1		moindr
# 1		douteux
# 1		humili
# 1		haineux
# 1		brûl
# 1		absolu
# 1		républicain
# 1		municipal
# 1		honnêt
# 1		beau
# 1		haut
# 1		hypocrit
# 1		prêt
# 1		populair
# 1		envah
# 1		nouveau
# 1		artist
# 1		l
# 1		bless
# 1		typiqu
# 1		viv
# 1		jaloux
# 1		bleu
# 1		miux
# 1		cher
# 1		enplus
# 1		continu
# 1		droit
# 1		déprav
# 1		affol
# 1		qulequ
# 1		compositeur
# 1		indifférent
# 1		superb
# 1		content
# 1		net
# 1		tent
# 1		grotesqu
# 1		quart
# 1		inquiet
# 1		vrai
# 1		placard
# 1		risibl
# 1		impuiss
# 1		admir
# 1		bon
# 1		futil
# 1		vraisembl
# 1		honor
# 1		lugubr
# 1		délégu
# 1		danger
# 1		semblabl
# 1		effroi
# 1		tragiqu
# 1		moral
# 1		accabl
# 1		sombr
# 1		facil
# 1		sympath
# 1		adjoint
# 1		injuri
# 1		suiv
# 1		trist
# 1		difficil
# 1		épouvant
# 1		dign
# 1		géner
# 1		flam
# 1		patriot
# 1		inouï
# 1		douch
# 1		insens
# 1		dem
# 1		sousl
# 1		terribl
# 1		indefatig
# 1		minc
# 1		surpren
# 1		faux
# 1		clair
# 1		intact
# 1		intelligent
# 1		polit
# 1		fidel
# 1		entier
# 1		opulent
# 1		compr
# 1		capabl
# 1		inexplic
# 1		nombreux
# 1		surprendr
# 1		cathol
# 1		puniss
# 1		sérieux
# None
#
# Les Antilles  -  1890-07-05
# -----------------------------
# 4		suiv
# 3		premi
# 3		nouvel
# 3		derni
# 2		nécessair
# 2		sinistr
# 2		viv
# 2		doulour
# 2		vrai
# 2		artist
# 1		fameux
# 1		consider
# 1		délégu
# 1		adroit
# 1		trist
# 1		semblabl
# 1		profond
# 1		insensibl
# 1		indifférent
# 1		égoïst
# 1		court
# 1		harmoni
# 1		anglais
# 1		colonial
# 1		flatteux
# 1		fast
# 1		sublim
# 1		terribl
# 1		grand
# 1		fatal
# 1		parf
# 1		be
# 1		heureux
# 1		beau
# 1		municipal
# 1		nobl
# 1		métropolitain
# 1		capabl
# 1		secour
# 1		géner
# 1		noir
# 1		humbl
# 1		placard
# 1		bel
# 1		infatig
# 1		officiel
# 1		second
# 1		malheur
# 1		rein
# 1		pauvr
# 1		musical
# None
#
# Journal officiel de la Guadeloupe  -  1890-07-08
# -----------------------------
# 2		franc
# 2		sinistr
# 2		récent
# 2		malheur
# 1		premi
# 1		bass
# 1		second
# 1		colonial
# 1		charit
# 1		législ
# 1		derni
# 1		publiqu
# 1		mont
# 1		strling
# 1		meilleur
# None
#
# Les Antilles  -  1890-07-09
# -----------------------------
# 6		derni
# 5		actuel
# 3		premi
# 3		suiv
# 3		nouvel
# 2		doulour
# 2		publiqu
# 2		haut
# 2		conven
# 2		colonial
# 2		franc
# 2		fauss
# 2		calm
# 2		involontair
# 2		grand
# 2		perfid
# 1		indign
# 1		just
# 1		récent
# 1		pareil
# 1		noir
# 1		vieil
# 1		lourd
# 1		opportun
# 1		moindr
# 1		lu
# 1		haineux
# 1		coupabl
# 1		louabl
# 1		populair
# 1		libr
# 1		contrair
# 1		nouveau
# 1		bas
# 1		officiel
# 1		simpl
# 1		lament
# 1		fièvreux
# 1		integr
# 1		compris
# 1		inconscient
# 1		viet
# 1		cher
# 1		regret
# 1		éloquent
# 1		sinistr
# 1		conditionnel
# 1		ennem
# 1		profond
# 1		auxqul
# 1		scandal
# 1		ous
# 1		courtois
# 1		coquet
# 1		évident
# 1		public
# 1		commercial
# 1		supposon
# 1		infim
# 1		sûr
# 1		vœu
# 1		entier
# 1		danger
# 1		civil
# 1		vast
# 1		viv
# 1		diocésain
# 1		total
# 1		facil
# 1		commun
# 1		serein
# 1		éloign
# 1		géner
# 1		exceptionnel
# 1		fourb
# 1		meilleur
# 1		fort
# 1		bel
# 1		possibl
# 1		second
# 1		magnif
# 1		perturb
# 1		dec
# 1		petit
# 1		sag
# 1		longu
# 1		cettecabal
# 1		bêt
# 1		agréabl
# 1		précédent
# 1		hom
# 1		susceptibl
# 1		malveil
# 1		moralis
# 1		polit
# 1		chaitabl
# 1		expédit
# 1		deceux
# 1		social
# 1		équatorial
# 1		ombrag
# 1		gros
# 1		muncipal
# 1		trist
# 1		orag
# 1		sérieux
# 1		sain
# None
#
# Les Colonies  -  1890-07-09
# -----------------------------
# 8		malheur
# 7		premi
# 6		seul
# 5		haut
# 5		grand
# 4		derni
# 3		publiqu
# 3		polit
# 3		miser
# 3		bon
# 3		pauvr
# 2		jeun
# 2		réactionnair
# 2		moindr
# 2		récent
# 2		mour
# 2		libr
# 2		bas
# 2		mauvais
# 2		viv
# 2		cher
# 2		odieux
# 2		coquet
# 2		content
# 2		import
# 2		facil
# 2		vérit
# 2		agress
# 2		injust
# 1		pervers
# 1		indign
# 1		lecorp
# 1		habituel
# 1		tapag
# 1		discrétionnair
# 1		pareil
# 1		ridicul
# 1		rapid
# 1		noir
# 1		noirc
# 1		lu
# 1		étreint
# 1		doulour
# 1		ien
# 1		conjur
# 1		infernal
# 1		fournais
# 1		bio
# 1		abstenus
# 1		honnêt
# 1		immens
# 1		patriot
# 1		nobl
# 1		louabl
# 1		press
# 1		monstrueux
# 1		nouveau
# 1		administr
# 1		officiel
# 1		sacrifi
# 1		bousin
# 1		indélicat
# 1		insulteur
# 1		sicair
# 1		oblig
# 1		conven
# 1		grossi
# 1		rédacteur
# 1		sinistr
# 1		nus
# 1		droit
# 1		respect
# 1		bass
# 1		haineux
# 1		matériel
# 1		honteux
# 1		larg
# 1		propr
# 1		filou
# 1		symmetr
# 1		trouv
# 1		franc
# 1		heureux
# 1		inconven
# 1		commercial
# 1		sûr
# 1		vrai
# 1		déplor
# 1		saltimbanqu
# 1		respon
# 1		plum
# 1		curel
# 1		pietr
# 1		fallaci
# 1		inavou
# 1		entier
# 1		numéros
# 1		prodigi
# 1		honor
# 1		gauch
# 1		danger
# 1		civil
# 1		suprêm
# 1		semblabl
# 1		définit
# 1		moral
# 1		farouch
# 1		vagabond
# 1		intérieur
# 1		infortun
# 1		marist
# 1		véreux
# 1		brul
# 1		brui
# 1		criminel
# 1		dur
# 1		déau
# 1		soutan
# 1		magnanim
# 1		dign
# 1		indiscut
# 1		épouvant
# 1		judiciair
# 1		plausibl
# 1		pitoi
# 1		étranger
# 1		absent
# 1		aurat
# 1		effrai
# 1		lament
# 1		suffoc
# 1		disparu
# 1		brûl
# 1		inaccessibl
# 1		hideux
# 1		délici
# 1		terribl
# 1		nouvel
# 1		exist
# 1		outrag
# 1		ivre
# 1		municipal
# 1		rôdeur
# 1		urt
# 1		eni
# 1		étrang
# 1		détest
# 1		perfid
# 1		téléphon
# 1		feu
# 1		sonor
# 1		moyen
# 1		ouvert
# 1		prudent
# 1		deuxiem
# 1		unanim
# 1		tten
# 1		actuel
# 1		imminent
# 1		tripl
# 1		sincer
# None
# ALL TEXT
# ----------
# 77		premi
# 67		grand
# 55		général
# 47		malheur
# 39		derni
# 36		bon
# 35		seul
# 30		sinistr
# 26		doulour
# 26		nouvel
# 22		bel
# 22		effroi
# 22		suiv
# 21		nombreux
# 19		terribl
# 19		publiqu
# 18		pauvr
# 17		nouveau
# 16		plein
# 16		haut
# 15		pareil
# 15		profond
# 15		petit
# 14		entier
# 14		municipal
# 14		colonial
# 14		possibl
# 13		cher
# 13		priv
# 13		nécessair
# 13		vrai
# 13		complet
# 13		civil
# 13		géner
# 12		prochain
# 12		moindr
# 11		consider
# 11		rich
# 11		noir
# 11		fort
# 10		miser
# 10		militair
# 10		polit
# 10		ancien
# 10		noirc
# 10		brûl
# 10		admir
# 10		incendi
# 10		viv
# 9		vast
# 9		énerg
# 9		beau
# 9		patriot
# 9		trist
# 9		ivre
# 8		récent
# 8		anglais
# 8		transatlant
# 8		vain
# 8		arriv
# 8		épouvant
# 8		officiel
# 8		semblabl
# 8		présent
# 8		immens
# 8		supérieur
# 7		lourd
# 7		commercial
# 7		vaill
# 7		franc
# 7		principal
# 7		sûr
# 7		probabl
# 7		actuel
# 6		matériel
# 6		mauv
# 6		mélancol
# 6		intelligent
# 6		pénibl
# 6		facil
# 6		photograph
# 6		lament
# 6		second
# 6		sag
# 6		énorm
# 6		heureux
# 6		difficil
# 6		larg
# 6		sympath
# 6		affreux
# 6		absent
# 6		sincer
# 5		honor
# 5		poign
# 5		jeun
# 5		simpl
# 5		précieux
# 5		deuxiem
# 5		commerc
# 5		propr
# 5		impuiss
# 5		sombr
# 5		exceptionnel
# 5		secour
# 5		honnêt
# 5		pet
# 5		prec
# 5		fauss
# 4		administr
# 4		droit
# 4		égal
# 4		public
# 4		inaccessibl
# 4		approxim
# 4		feu
# 4		irrépar
# 4		magnif
# 4		dem
# 4		centralis
# 4		social
# 4		court
# 4		télégraph
# 4		industriel
# 4		quelconqu
# 4		intérieur
# 4		sœur
# 4		bass
# 4		charit
# 4		lugubr
# 4		long
# 4		longu
# 4		mobili
# 4		bref
# 4		momentan
# 4		injust
# 4		sérieux
# 4		efficac
# 4		bas
# 4		conditionnel
# 4		désert
# 4		lazul
# 4		import
# 4		mer
# 4		infortun
# 4		dur
# 4		troisiem
# 4		haineux
# 4		spécial
# 4		immédiat
# 4		indign
# 4		faibl
# 4		abond
# 4		suprêm
# 4		funest
# 4		brul
# 4		meilleur
# 4		alarm
# 4		gross
# 3		odieux
# 3		vieil
# 3		incap
# 3		xxxi
# 3		pass
# 3		coquet
# 3		net
# 3		patr
# 3		excess
# 3		respect
# 3		vraisembl
# 3		danger
# 3		moral
# 3		français
# 3		malad
# 3		fraternel
# 3		indien
# 3		sis
# 3		inform
# 3		content
# 3		infim
# 3		prodigi
# 3		diocésain
# 3		dign
# 3		part
# 3		consult
# 3		indescriptibl
# 3		inouï
# 3		faux
# 3		compr
# 3		charm
# 3		nobl
# 3		prêt
# 3		télégraphi
# 3		artist
# 3		guadeloupéen
# 3		redout
# 3		étroit
# 3		confort
# 3		particuli
# 3		étreint
# 3		effrai
# 3		étrang
# 3		moyen
# 3		unanim
# 3		just
# 3		habituel
# 3		innombr
# 3		libr
# 3		impossibl
# 3		mécan
# 3		chimiqu
# 3		réun
# 3		fonci
# 3		conven
# 3		urgent
# 3		ouvert
# 3		honteux
# 3		sensibl
# 3		inquiet
# 3		brui
# 3		pitoi
# 3		humain
# 3		précédent
# 3		personnel
# 3		perfid
# 3		nu
# 3		brasi
# 2		dist
# 2		inutil
# 2		fournais
# 2		religi
# 2		républicain
# 2		util
# 2		mour
# 2		exact
# 2		conseilleur
# 2		mauvais
# 2		surexcit
# 2		regret
# 2		constern
# 2		affol
# 2		mutuel
# 2		néfast
# 2		joyeux
# 2		réactionnair
# 2		délégu
# 2		barbar
# 2		formid
# 2		paralyt
# 2		commun
# 2		injuri
# 2		funebr
# 2		impitoi
# 2		morn
# 2		calm
# 2		involontair
# 2		inextinguibl
# 2		élev
# 2		appel
# 2		rigid
# 2		placard
# 2		vrais
# 2		infatig
# 2		porteur
# 2		ram
# 2		extraordinair
# 2		métropolitain
# 2		trouv
# 2		polici
# 2		lu
# 2		anim
# 2		dan
# 2		malhonnêt
# 2		l
# 2		bless
# 2		étincel
# 2		agress
# 2		hypothécair
# 2		navr
# 2		influent
# 2		atterr
# 2		pût
# 2		pur
# 2		fréquent
# 2		radical
# 2		sacr
# 2		adjoint
# 2		impéri
# 2		douleur
# 2		rar
# 2		blanch
# 2		invraisembl
# 2		roug
# 2		dévou
# 2		séver
# 2		vulgair
# 2		froid
# 2		superb
# 2		desperson
# 2		populair
# 2		lacrima
# 2		inimagin
# 2		grav
# 2		menac
# 2		indifférent
# 2		télégramm
# 2		sain
# 2		insuffis
# 2		insond
# 2		soucieux
# 2		popul
# 2		précis
# 2		adroit
# 2		désesper
# 2		dessin
# 2		modern
# 2		infect
# 2		monstreux
# 2		affirm
# 2		ain
# 2		rigour
# 2		exist
# 2		fum
# 2		multicolor
# 2		opulent
# 2		capabl
# 2		respons
# 2		exampl
# 2		obscur
# 2		touch
# 2		rapid
# 2		curieux
# 2		louabl
# 2		press
# 2		américain
# 2		cabl
# 2		évident
# 2		prob
# 2		compris
# 2		louch
# 2		rougeâtr
# 2		central
# 2		affam
# 2		écarlat
# 2		ferm
# 2		artifici
# 2		vérit
# 2		magnanim
# 2		écrit
# 2		superflus
# 2		alimentair
# 2		intim
# 2		cruel
# 2		voisin
# 2		incomplet
# 2		famin
# 2		pir
# 2		débat
# 2		inconnu
# 1		adminstr
# 1		légitim
# 1		tourn
# 1		pervers
# 1		ridicul
# 1		sufferer
# 1		humili
# 1		fatal
# 1		vert
# 1		hypocrit
# 1		coupabl
# 1		envah
# 1		affect
# 1		chapel
# 1		bousin
# 1		typiqu
# 1		méconnaiss
# 1		surcri
# 1		jaloux
# 1		miux
# 1		impassibl
# 1		enti
# 1		det
# 1		enplus
# 1		auxqul
# 1		foll
# 1		détest
# 1		sub
# 1		sum
# 1		poison
# 1		tabernacl
# 1		chaleur
# 1		harilsd
# 1		canonad
# 1		envieux
# 1		respon
# 1		sonor
# 1		risibl
# 1		vif
# 1		électoral
# 1		tranquill
# 1		tragiqu
# 1		scandal
# 1		distinct
# 1		criminel
# 1		soutan
# 1		apprend
# 1		indiscut
# 1		judiciair
# 1		flam
# 1		guadaloupéen
# 1		suffoc
# 1		infernal
# 1		caveau
# 1		dec
# 1		couvert
# 1		clair
# 1		rôdeur
# 1		épiscopal
# 1		eni
# 1		hom
# 1		divin
# 1		botan
# 1		blasphématoir
# 1		souverain
# 1		deceux
# 1		égoïst
# 1		ombrag
# 1		gros
# 1		trois
# 1		splendid
# 1		sech
# 1		minuti
# 1		muncipal
# 1		ornement
# 1		bienheur
# 1		imminent
# 1		mortel
# 1		tapag
# 1		flétriss
# 1		silenci
# 1		douteux
# 1		sépar
# 1		fauch
# 1		absolu
# 1		prosper
# 1		abstenus
# 1		contrair
# 1		critiqu
# 1		fièvreux
# 1		pan
# 1		sicair
# 1		inconscient
# 1		oblig
# 1		courag
# 1		éloquent
# 1		rédacteur
# 1		continu
# 1		ennem
# 1		prssant
# 1		déprav
# 1		horribl
# 1		cettecabal
# 1		our
# 1		cœur
# 1		pullul
# 1		laid
# 1		ressemblenet
# 1		inconven
# 1		quart
# 1		organ
# 1		viet
# 1		croiss
# 1		curel
# 1		désol
# 1		brigandag
# 1		inend
# 1		croul
# 1		gauch
# 1		perturb
# 1		suffis
# 1		téléphon
# 1		surpren
# 1		angoiss
# 1		tardiv
# 1		saint
# 1		vêtu
# 1		parf
# 1		digu
# 1		nus
# 1		puiss
# 1		debitor
# 1		serv
# 1		contrari
# 1		fléaux
# 1		chaitabl
# 1		stéril
# 1		hideux
# 1		rad
# 1		délici
# 1		minc
# 1		martiniquais
# 1		déjàpénitent
# 1		audaci
# 1		originair
# 1		couch
# 1		déchir
# 1		obligatoir
# 1		vibr
# 1		pratiqu
# 1		expédit
# 1		émouv
# 1		fidel
# 1		extraordnair
# 1		charg
# 1		étendu
# 1		latéral
# 1		douch
# 1		bateau
# 1		cathol
# 1		indompt
# 1		puniss
# 1		occidental
# 1		mort
# 1		occasion
# 1		oppress
# 1		chrétien
# 1		supposon
# 1		ruineux
# 1		discrétionnair
# 1		lde
# 1		ment
# 1		activ
# 1		cadavr
# 1		ien
# 1		local
# 1		tripl
# 1		sos
# 1		symmetr
# 1		indélicat
# 1		integr
# 1		insulteur
# 1		rein
# 1		grad
# 1		bleu
# 1		grossi
# 1		accabl
# 1		national
# 1		nul
# 1		qulequ
# 1		led
# 1		compositeur
# 1		sublim
# 1		filou
# 1		tent
# 1		encombr
# 1		amer
# 1		déplor
# 1		c
# 1		saltimbanqu
# 1		opuent
# 1		mont
# 1		futil
# 1		uni
# 1		définit
# 1		insensibl
# 1		suppli
# 1		guadeloupemartin
# 1		marist
# 1		véreux
# 1		auxhabit
# 1		attendr
# 1		déau
# 1		inexor
# 1		fourb
# 1		plausibl
# 1		aurat
# 1		solid
# 1		plain
# 1		disparu
# 1		insens
# 1		quêt
# 1		esxcess
# 1		sousl
# 1		serein
# 1		éloign
# 1		spacieux
# 1		bêt
# 1		pocel
# 1		agréabl
# 1		outrag
# 1		situ
# 1		communal
# 1		effac
# 1		harmoni
# 1		ému
# 1		malveil
# 1		moralis
# 1		ordinair
# 1		desecour
# 1		sangl
# 1		assist
# 1		accompl
# 1		effect
# 1		bibliqu
# 1		héroïqu
# 1		surprendr
# 1		musical
# 1		acharn
# 1		connus
# 1		discord
# 1		lecorp
# 1		violent
# 1		diosésain
# 1		extraodinair
# 1		intéress
# 1		stupeur
# 1		vindiqu
# 1		volontair
# 1		conjur
# 1		ami
# 1		bio
# 1		gris
# 1		usini
# 1		monstrueux
# 1		sacrifi
# 1		législ
# 1		équatorial
# 1		lapopul
# 1		détach
# 1		intact
# 1		courtois
# 1		fou
# 1		total
# 1		décombr
# 1		tendr
# 1		troup
# 1		be
# 1		émus
# 1		grotesqu
# 1		virulent
# 1		rud
# 1		provisoir
# 1		anormal
# 1		plum
# 1		pietr
# 1		fallaci
# 1		inavou
# 1		numéros
# 1		ide
# 1		miracul
# 1		ravag
# 1		inexprim
# 1		farouch
# 1		vagabond
# 1		opportun
# 1		savan
# 1		fast
# 1		invisibl
# 1		palliat
# 1		vieillard
# 1		susceptibl
# 1		destructric
# 1		prochin
# 1		étranger
# 1		auxiliair
# 1		âgé
# 1		ue
# 1		somptueux
# 1		fameux
# 1		indefatig
# 1		atten
# 1		directemenet
# 1		ous
# 1		desusin
# 1		spontan
# 1		urt
# 1		noirâtr
# 1		larmesqu
# 1		flatteux
# 1		décourag
# 1		supplementair
# 1		vœu
# 1		spirituel
# 1		enquarti
# 1		épuis
# 1		préced
# 1		strling
# 1		prudent
# 1		humbl
# 1		inexplic
# 1		funérair
# 1		orag
# 1		tten
# None

# %%
tags=pos_tag(all_documents['tokens'])
nouns=get_pos_tags(tags,'n') #get all the nouns from the pos tagger
filtered_nouns = filter_stopwords(nouns,french_stopwords) #filter the veronis stopwords out of the noun tags
noun_count = Counter(filtered_nouns) #count the filtered nouns
noun_count = normalize_counts(noun_count) #normalize the counts by how many words are in the articles related to Martinique
noun_count = sort_dictionary(noun_count) #sort the dictionary into a sorted tuple list
print_sorted_dictionary(noun_count) #print the sorted tuples

# %%
search_pos(tags,'catastrophe','a')

# %%
sorted_stemmed_words = sort_dictionary(stemmed_word_count)
print_sorted_dictionary(sorted_stemmed_words)

# %%
print Counter([tag[1] for tag in tags]) #count the parts of speech

# %%
for document in documents: print document['newspaper'],': ',document['date'],'\n\n',document['raw'],'\n\n*******\n\n' #print out all the paragraphs from each xml file

# %%
# print the concordance of a term for all of our nltk documents that had been read in from the xml files
for document in documents:
    print "DATE: %s \t NEWSPAPER: %s" %(document['date'],document['newspaper'])
    print '------'
    print document['text'].concordance('Martinique')
    print '\n'

# %%
for document in documents: print "NEWSPAPER: %s \t DATE: %s \t WORD COUNT: %s \t CHARACTER COUNT: %s" %(document['newspaper'],document['date'],len(document['tokens']),len(document['raw']))

# %%
# NLTK COLLOCATIONS
from nltk.collocations import *
bigram_measures = nltk.collocations.BigramAssocMeasures()
trigram_measures = nltk.collocations.TrigramAssocMeasures()

#tags = pos_tag(all_documents['tokens'])
#collocationtokens=all_documents['tokens']
collocationtokens=coloniestokens

words=[w.lower() for w in collocationtokens if w.isalpha()] #filter out all punctuation and numbers
finder = BigramCollocationFinder.from_words(words)
#finder.apply_freq_filter(3) #filter out all words that appear less than 3 times
finder.apply_word_filter(lambda w: w in french_stopwords) #filter out the french stopwords

scored = finder.score_ngrams(bigram_measures.raw_freq)
#sorted(bigram for bigram, score in scored)
print "SOURCE\tTARGET\tWEIGHT"
for bigram in scored:
   for word in bigram[0]:
        print word,'\t',
   print bigram[1]
        
#get the nbest measures
#finder.nbest(bigram_measures.pmi,10)
# Out:
# SOURCE	TARGET	WEIGHT
# journal 	officiel 	0.000492894109915
# pareil 	cas 	0.000328596073277
# dépêche 	suivante 	0.000246447054958
# grandeur 	monseigneur 	0.000246447054958
# lundi 	soir 	0.000246447054958
# marché 	couvert 	0.000246447054958
# mercredi 	dernier 	0.000246447054958
# trop 	tard 	0.000246447054958
# adoremus 	in 	0.000164298036638
# angoisse 	désespérante 	0.000164298036638
# chef 	civil 	0.000164298036638
# compagnie 	transatlantique 	0.000164298036638
# conseil 	général 	0.000164298036638
# conseil 	privé 	0.000164298036638
# cru 	devoir 	0.000164298036638
# desolatione 	desolata 	0.000164298036638
# devoir 	prendre 	0.000164298036638
# dimanche 	prochain 	0.000164298036638
# extrèmement 	douloureuses 	0.000164298036638
# fausses 	là 	0.000164298036638
# feraient 	volontairement 	0.000164298036638
# force 	policière 	0.000164298036638
# forme 	conditionnelle 	0.000164298036638
# germain 	casse 	0.000164298036638
# journaux 	guadeloupéens 	0.000164298036638
# jugé 	bon 	0.000164298036638
# juin 	courant 	0.000164298036638
# maison 	lalung 	0.000164298036638
# mesures 	immédiates 	0.000164298036638
# mesures 	propres 	0.000164298036638
# noire 	ville 	0.000164298036638
# petite 	france 	0.000164298036638
# peut 	dire 	0.000164298036638
# plein 	air 	0.000164298036638
# premier 	secours 	0.000164298036638
# premiers 	secours 	0.000164298036638
# première 	heure 	0.000164298036638
# première 	liste 	0.000164298036638
# procureur 	général 	0.000164298036638
# propagateursde 	fausses 	0.000164298036638
# riou 	vicaire 	0.000164298036638
# saines 	idées 	0.000164298036638
# seule 	vérité 	0.000164298036638
# vicaire 	général 	0.000164298036638
# ville 	entière 	0.000164298036638
# abbé 	lecornu 	8.21490183192e-05
# abondant 	trouvera 	8.21490183192e-05
# abris 	commission 	8.21490183192e-05
# actuelle 	passée 	8.21490183192e-05
# adroit 	entrefilet 	8.21490183192e-05
# advienne 	tant 	8.21490183192e-05
# affectée 	malheur 	8.21490183192e-05
# affiché 	partout 	8.21490183192e-05
# affreuse 	misère 	8.21490183192e-05
# agi 	ave 	8.21490183192e-05
# agir 	constamment 	8.21490183192e-05
# agréez 	monsieur 	8.21490183192e-05
# aide 	auxhabitants 	8.21490183192e-05
# ailleurs 	poursuivies 	8.21490183192e-05
# ainsi 	dire 	8.21490183192e-05
# air 	couchant 	8.21490183192e-05
# alexandre 	comairas 	8.21490183192e-05
# alexandre 	percepteur 	8.21490183192e-05
# allait 	commencer 	8.21490183192e-05
# allait 	mettre 	8.21490183192e-05
# allé 	porter 	8.21490183192e-05
# alué 	idem 	8.21490183192e-05
# amassés 	péniblement 	8.21490183192e-05
# amicales 	relations 	8.21490183192e-05
# amies 	chassés 	8.21490183192e-05
# ancien 	chef 	8.21490183192e-05
# ancienne 	église 	8.21490183192e-05
# annonce 	sacs 	8.21490183192e-05
# annonceront 	dimanche 	8.21490183192e-05
# annoncé 	mercredi 	8.21490183192e-05
# août 	vu 	8.21490183192e-05
# appel 	nouveau 	8.21490183192e-05
# appelait 	état 	8.21490183192e-05
# appris 	catastrophe 	8.21490183192e-05
# appât 	lundi 	8.21490183192e-05
# ardent 	presque 	8.21490183192e-05
# ardeurs 	excessives 	8.21490183192e-05
# argent 	embarrasse 	8.21490183192e-05
# articles 	récemment 	8.21490183192e-05
# artistes 	appelés 	8.21490183192e-05
# artistes 	prétz 	8.21490183192e-05
# artistique 	donneront 	8.21490183192e-05
# asile 	hélas 	8.21490183192e-05
# assemblée 	exclusivement 	8.21490183192e-05
# assez 	loué 	8.21490183192e-05
# assez 	spacieux 	8.21490183192e-05
# assis 	étendus 	8.21490183192e-05
# atteint 	également 	8.21490183192e-05
# attenant 	patientos 	8.21490183192e-05
# attendrons 	impatiemment 	8.21490183192e-05
# audemar 	henri 	8.21490183192e-05
# aumôniers 	annonceront 	8.21490183192e-05
# aussitôt 	rejetées 	8.21490183192e-05
# autant 	plaquées 	8.21490183192e-05
# autorités 	civiles 	8.21490183192e-05
# autorités 	coloniales 	8.21490183192e-05
# autorités 	municipales 	8.21490183192e-05
# autorités 	rarement 	8.21490183192e-05
# ave 	trop 	8.21490183192e-05
# avont 	dit 	8.21490183192e-05
# banque 	guadeloupéenne 	8.21490183192e-05
# baraquements 	destinés 	8.21490183192e-05
# bateau 	envoyé 	8.21490183192e-05
# bateau 	monseigneur 	8.21490183192e-05
# bateaux 	revinrent 	8.21490183192e-05
# batiment 	assez 	8.21490183192e-05
# beau 	avoir 	8.21490183192e-05
# beau 	chiffre 	8.21490183192e-05
# beau 	pensionnat 	8.21490183192e-05
# beaucoup 	supérieure 	8.21490183192e-05
# beaux 	débuts 	8.21490183192e-05
# beaux 	hôtels 	8.21490183192e-05
# beillouir 	négociant 	8.21490183192e-05
# bel 	hospice 	8.21490183192e-05
# bel 	usage 	8.21490183192e-05
# bele 	église 	8.21490183192e-05
# belle 	cathédrale 	8.21490183192e-05
# belle 	devise 	8.21490183192e-05
# belle 	eglise 	8.21490183192e-05
# belle 	figure 	8.21490183192e-05
# belle 	ville 	8.21490183192e-05
# belle 	étoile 	8.21490183192e-05
# besoin 	appuyé 	8.21490183192e-05
# besoin 	grandement 	8.21490183192e-05
# besoins 	cablez 	8.21490183192e-05
# biblique 	desolatione 	8.21490183192e-05
# bienfaisance 	matérielle 	8.21490183192e-05
# bienfaisance 	spontanée 	8.21490183192e-05
# bilan 	tant 	8.21490183192e-05
# blanchard 	capitaine 	8.21490183192e-05
# blénac 	bord 	8.21490183192e-05
# bon 	nombre 	8.21490183192e-05
# bon 	vouloir 	8.21490183192e-05
# bonheur 	monseigneur 	8.21490183192e-05
# bonne 	distance 	8.21490183192e-05
# bonne 	ville 	8.21490183192e-05
# bonne 	volonté 	8.21490183192e-05
# bons 	commenceraient 	8.21490183192e-05
# bons 	fruits 	8.21490183192e-05
# borde 	fils 	8.21490183192e-05
# boucher 	adressait 	8.21490183192e-05
# boucherle 	journal 	8.21490183192e-05
# bour 	maisons 	8.21490183192e-05
# bourgs 	dirigez 	8.21490183192e-05
# bourses 	prêtons 	8.21490183192e-05
# braves 	enfants 	8.21490183192e-05
# bref 	délai 	8.21490183192e-05
# brèches 	profondes 	8.21490183192e-05
# but 	louable 	8.21490183192e-05
# cablez 	nouvelles 	8.21490183192e-05
# cablez 	renseignements 	8.21490183192e-05
# cablogramme 	suivant 	8.21490183192e-05
# cachet 	général 	8.21490183192e-05
# cadavres 	humains 	8.21490183192e-05
# calcinés 	jadis 	8.21490183192e-05
# calculée 	raffinée 	8.21490183192e-05
# calme 	tant 	8.21490183192e-05
# calmer 	afinede 	8.21490183192e-05
# calomnies 	érigées 	8.21490183192e-05
# camp 	balata 	8.21490183192e-05
# camp 	rade 	8.21490183192e-05
# canonade 	lugubre 	8.21490183192e-05
# capitaine 	porion 	8.21490183192e-05
# carmené 	rend 	8.21490183192e-05
# cas 	marche 	8.21490183192e-05
# cas 	pouvaient 	8.21490183192e-05
# cas 	trop 	8.21490183192e-05
# catastrophe 	arrivée 	8.21490183192e-05
# catastrophe 	inouïe 	8.21490183192e-05
# cathédrale 	incendiée 	8.21490183192e-05
# cause 	incendie 	8.21490183192e-05
# causes 	grand 	8.21490183192e-05
# ccumulé 	tant 	8.21490183192e-05
# cercle 	artistique 	8.21490183192e-05
# cesse 	aggravés 	8.21490183192e-05
# chaitable 	composée 	8.21490183192e-05
# chaleur 	fera 	8.21490183192e-05
# chaleureux 	appel 	8.21490183192e-05
# chapelle 	latérale 	8.21490183192e-05
# chapitre 	xxxi 	8.21490183192e-05
# charitable 	conduite 	8.21490183192e-05
# charité 	doit 	8.21490183192e-05
# charité 	publique 	8.21490183192e-05
# charités 	effectives 	8.21490183192e-05
# charles 	pernain 	8.21490183192e-05
# charmant 	magnifique 	8.21490183192e-05
# chassés 	bientôt 	8.21490183192e-05
# chef 	civilde 	8.21490183192e-05
# chef 	vénéré 	8.21490183192e-05
# chefs 	civils 	8.21490183192e-05
# cher 	cete 	8.21490183192e-05
# chers 	coopérateurs 	8.21490183192e-05
# chers 	frères 	8.21490183192e-05
# chiffre 	considérable 	8.21490183192e-05
# chiffre 	hélas 	8.21490183192e-05
# chiffre 	total 	8.21490183192e-05
# chiffre 	vu 	8.21490183192e-05
# chose 	appartenant 	8.21490183192e-05
# chose 	impossible 	8.21490183192e-05
# chose 	malheur 	8.21490183192e-05
# chose 	noircis 	8.21490183192e-05
# chose 	utile 	8.21490183192e-05
# chère 	portion 	8.21490183192e-05
# chère 	sœur 	8.21490183192e-05
# chère 	église 	8.21490183192e-05
# circonstances 	malheureuses 	8.21490183192e-05
# circontances 	devaient 	8.21490183192e-05
# circulent 	veillant 	8.21490183192e-05
# citoyens 	intègres 	8.21490183192e-05
# cité 	anéantie 	8.21490183192e-05
# clerc 	fernand 	8.21490183192e-05
# cmme 	prescrit 	8.21490183192e-05
# cnsul 	français 	8.21490183192e-05
# colonial 	alexandre 	8.21490183192e-05
# colonial 	général 	8.21490183192e-05
# colonie 	décide 	8.21490183192e-05
# colonie 	envoie 	8.21490183192e-05
# colonie 	offrent 	8.21490183192e-05
# colonie 	rendu 	8.21490183192e-05
# colonie 	volons 	8.21490183192e-05
# comairas 	cre 	8.21490183192e-05
# commenceraient 	ainsi 	8.21490183192e-05
# comment 	compatir 	8.21490183192e-05
# comment 	consoler 	8.21490183192e-05
# comment 	possible 	8.21490183192e-05
# comment 	pu 	8.21490183192e-05
# comment 	énumérer 	8.21490183192e-05
# commercial 	hall 	8.21490183192e-05
# commissaires 	distributeurs 	8.21490183192e-05
# commission 	ainsi 	8.21490183192e-05
# commission 	desecours 	8.21490183192e-05
# commission 	instituée 	8.21490183192e-05
# commission 	préparera 	8.21490183192e-05
# commission 	tendant 	8.21490183192e-05
# communes 	omises 	8.21490183192e-05
# compatriotes 	malheureux 	8.21490183192e-05
# complète 	détresse 	8.21490183192e-05
# complètement 	guadeloupe 	8.21490183192e-05
# complètes 	victimes 	8.21490183192e-05
# composée 	sérieux 	8.21490183192e-05
# comprendra 	billets 	8.21490183192e-05
# comprendra 	facilement 	8.21490183192e-05
# confusion 	devient 	8.21490183192e-05
# connu 	campait 	8.21490183192e-05
# conscience 	coupable 	8.21490183192e-05
# conseil 	municipal 	8.21490183192e-05
# conseil 	souverain 	8.21490183192e-05
# conseiller 	général 	8.21490183192e-05
# conseiller 	privé 	8.21490183192e-05
# conseillers 	généraux 	8.21490183192e-05
# considérable 	dévoués 	8.21490183192e-05
# considérable 	population 	8.21490183192e-05
# consommée 	atterré 	8.21490183192e-05
# constamment 	demandés 	8.21490183192e-05
# constamment 	tant 	8.21490183192e-05
# constaté 	souvent 	8.21490183192e-05
# consterné 	pénétré 	8.21490183192e-05
# construction 	église 	8.21490183192e-05
# consul 	français 	8.21490183192e-05
# contemplions 	œil 	8.21490183192e-05
# contenir 	os 	8.21490183192e-05
# contenir 	tant 	8.21490183192e-05
# contraire 	passent 	8.21490183192e-05
# contrariée 	compromise 	8.21490183192e-05
# convenable 	cla 	8.21490183192e-05
# coopéré 	autant 	8.21490183192e-05
# corps 	humain 	8.21490183192e-05
# corps 	élu 	8.21490183192e-05
# correspondants 	adminstratifs 	8.21490183192e-05
# cosnumé 	disparu 	8.21490183192e-05
# coup 	créées 	8.21490183192e-05
# coup 	produisait 	8.21490183192e-05
# coup 	terrible 	8.21490183192e-05
# courageusement 	monseiur 	8.21490183192e-05
# courant 	criant 	8.21490183192e-05
# courtois 	régler 	8.21490183192e-05
# couvert 	trouverait 	8.21490183192e-05
# coûté 	francs 	8.21490183192e-05
# cre 	gerard 	8.21490183192e-05
# cris 	déchirants 	8.21490183192e-05
# crise 	surcrière 	8.21490183192e-05
# critique 	gouverneur 	8.21490183192e-05
# croyait 	vu 	8.21490183192e-05
# croyions 	jamas 	8.21490183192e-05
# croyions 	presque 	8.21490183192e-05
# croyons 	sage 	8.21490183192e-05
# cru 	attaqué 	8.21490183192e-05
# cruellement 	agréez 	8.21490183192e-05
# cruellement 	frappée 	8.21490183192e-05
# crumble 	donnez 	8.21490183192e-05
# crédit 	foncier 	8.21490183192e-05
# crédit 	pareille 	8.21490183192e-05
# cœpit 	facere 	8.21490183192e-05
# cœur 	chrétien 	8.21490183192e-05
# cœur 	oppressé 	8.21490183192e-05
# cœur 	âme 	8.21490183192e-05
# cœurs 	prêtons 	8.21490183192e-05
# cœurs 	sensibles 	8.21490183192e-05
# debitor 	sum 	8.21490183192e-05
# dece 	vaste 	8.21490183192e-05
# dela 	haute 	8.21490183192e-05
# demande 	crédit 	8.21490183192e-05
# demandons 	intelligence 	8.21490183192e-05
# demi 	feuill 	8.21490183192e-05
# demie 	soir 	8.21490183192e-05
# denotre 	ville 	8.21490183192e-05
# dernier 	incendie 	8.21490183192e-05
# dernier 	juillet 	8.21490183192e-05
# derniers 	temps 	8.21490183192e-05
# dernière 	mine 	8.21490183192e-05
# dernières 	victoires 	8.21490183192e-05
# descendus 	rapidement 	8.21490183192e-05
# deslandes 	roy 	8.21490183192e-05
# destination 	utile 	8.21490183192e-05
# destructrice 	profitant 	8.21490183192e-05
# devenue 	audacieuse 	8.21490183192e-05
# deviennent 	instinctivement 	8.21490183192e-05
# devient 	attendrissante 	8.21490183192e-05
# devient 	bête 	8.21490183192e-05
# devise 	omnibus 	8.21490183192e-05
# devons 	avouer 	8.21490183192e-05
# devrait 	autant 	8.21490183192e-05
# dieu 	comment 	8.21490183192e-05
# dieu 	envoie 	8.21490183192e-05
# dieu 	oui 	8.21490183192e-05
# difficultés 	fallait 	8.21490183192e-05
# difficultés 	sas 	8.21490183192e-05
# digue 	abbé 	8.21490183192e-05
# dimanche 	charles 	8.21490183192e-05
# dimanche 	dernier 	8.21490183192e-05
# dimanche 	juillet 	8.21490183192e-05
# diocésaines 	ouverte 	8.21490183192e-05
# dire 	scandaleuse 	8.21490183192e-05
# directeur 	intérieur 	8.21490183192e-05
# discordes 	sociales 	8.21490183192e-05
# disgrace 	comment 	8.21490183192e-05
# disons 	manière 	8.21490183192e-05
# disparu 	confondu 	8.21490183192e-05
# dissensions 	politiques 	8.21490183192e-05
# distance 	feu 	8.21490183192e-05
# dit 	croyait 	8.21490183192e-05
# dit 	numéro 	8.21490183192e-05
# dit 	oui 	8.21490183192e-05
# dits 	petits 	8.21490183192e-05
# divine 	charité 	8.21490183192e-05
# divine 	trouvera 	8.21490183192e-05
# divisions 	subsistent 	8.21490183192e-05
# docteur 	bouvier 	8.21490183192e-05
# docteur 	olmeia 	8.21490183192e-05
# docteur 	olméta 	8.21490183192e-05
# doit 	agir 	8.21490183192e-05
# doit 	pu 	8.21490183192e-05
# doit 	rendre 	8.21490183192e-05
# doivent 	reconstruire 	8.21490183192e-05
# doivent 	remplir 	8.21490183192e-05
# don 	généreux 	8.21490183192e-05
# donne 	espoir 	8.21490183192e-05
# donnez 	francs 	8.21490183192e-05
# donnèrent 	noms 	8.21490183192e-05
# donné 	poursuivrait 	8.21490183192e-05
# donné 	tête 	8.21490183192e-05
# dons 	générosité 	8.21490183192e-05
# dormir 	tranquilles 	8.21490183192e-05
# douces 	émotions 	8.21490183192e-05
# douleurs 	hélas 	8.21490183192e-05
# douloureuse 	fameuse 	8.21490183192e-05
# douloureuse 	émotion 	8.21490183192e-05
# douloureuses 	circonstances 	8.21490183192e-05
# douloureux 	écho 	8.21490183192e-05
# doute 	personnes 	8.21490183192e-05
# doutons 	pa 	8.21490183192e-05
# drames 	lamentables 	8.21490183192e-05
# droits 	sentiments 	8.21490183192e-05
# ds 	souscriptions 	8.21490183192e-05
# duquesnay 	maire 	8.21490183192e-05
# durera 	tant 	8.21490183192e-05
# dus 	parfois 	8.21490183192e-05
# dávoir 	rallumé 	8.21490183192e-05
# débris 	échappés 	8.21490183192e-05
# débuts 	resteront 	8.21490183192e-05
# décisions 	suprêmes 	8.21490183192e-05
# déclarait 	dimanche 	8.21490183192e-05
# déclèmy 	lavigne 	8.21490183192e-05
# décombres 	murs 	8.21490183192e-05
# défense 	permis 	8.21490183192e-05
# définir 	catastrophe 	8.21490183192e-05
# déposée 	chambre 	8.21490183192e-05
# dépouilles 	commençaient 	8.21490183192e-05
# dépêche 	annonce 	8.21490183192e-05
# dépêche 	reçue 	8.21490183192e-05
# désert 	tombeau 	8.21490183192e-05
# désespérante 	dit 	8.21490183192e-05
# déshonneur 	gouverné 	8.21490183192e-05
# désolant 	tableu 	8.21490183192e-05
# désolation 	croissante 	8.21490183192e-05
# désolation 	desolatione 	8.21490183192e-05
# détonations 	formidables 	8.21490183192e-05
# détresse 	recevrait 	8.21490183192e-05
# détruit 	martinique 	8.21490183192e-05
# dévastation 	pro 	8.21490183192e-05
# déviant 	presbyère 	8.21490183192e-05
# dévouement 	admirable 	8.21490183192e-05
# dévouement 	mère 	8.21490183192e-05
# dún 	navire 	8.21490183192e-05
# dû 	passer 	8.21490183192e-05
# dûr 	indifférent 	8.21490183192e-05
# ecoles 	garçons 	8.21490183192e-05
# effets 	courant 	8.21490183192e-05
# effroyable 	chaos 	8.21490183192e-05
# eglise 	presbytère 	8.21490183192e-05
# embarrasse 	tant 	8.21490183192e-05
# embellie 	entretenue 	8.21490183192e-05
# embrasé 	dufléau 	8.21490183192e-05
# employons 	signifie 	8.21490183192e-05
# empressement 	égal 	8.21490183192e-05
# enfants 	atterré 	8.21490183192e-05
# enfants 	vibre 	8.21490183192e-05
# enfants 	éprouvés 	8.21490183192e-05
# enlevé 	transporté 	8.21490183192e-05
# ennemis 	instinctifs 	8.21490183192e-05
# enregistrement 	eglise 	8.21490183192e-05
# enregistrée 	partout 	8.21490183192e-05
# ensuite 	part 	8.21490183192e-05
# entière 	allait 	8.21490183192e-05
# entière 	our 	8.21490183192e-05
# entièrement 	brulé 	8.21490183192e-05
# entièrement 	dévorée 	8.21490183192e-05
# entrefilet 	suivant 	8.21490183192e-05
# envoyaient 	francs 	8.21490183192e-05
# envoyer 	bateau 	8.21490183192e-05
# erreurs 	involontaires 	8.21490183192e-05
# esprits 	affolés 	8.21490183192e-05
# espérons 	adorons 	8.21490183192e-05
# estsans 	bornes 	8.21490183192e-05
# eté 	particulièrement 	8.21490183192e-05
# eustache 	nicole 	8.21490183192e-05
# exceptionnelle 	occasion 	8.21490183192e-05
# exclusivement 	chaitable 	8.21490183192e-05
# existela 	regrettable 	8.21490183192e-05
# exprimée 	mieux 	8.21490183192e-05
# extraordinaire 	fermelé 	8.21490183192e-05
# faible 	moyen 	8.21490183192e-05
# faible 	palliatif 	8.21490183192e-05
# faible 	partie 	8.21490183192e-05
# faim 	mourant 	8.21490183192e-05
# faim 	oui 	8.21490183192e-05
# faire 	appel 	8.21490183192e-05
# faire 	doner 	8.21490183192e-05
# faire 	généreusement 	8.21490183192e-05
# faire 	intervenir 	8.21490183192e-05
# faire 	maintenant 	8.21490183192e-05
# faire 	parvenir 	8.21490183192e-05
# faire 	parvenirleurs 	8.21490183192e-05
# faire 	peut 	8.21490183192e-05
# faire 	traverser 	8.21490183192e-05
# faisaient 	entendre 	8.21490183192e-05
# faisait 	presque 	8.21490183192e-05
# faisant 	factions 	8.21490183192e-05
# faisons 	appel 	8.21490183192e-05
# faisons 	trève 	8.21490183192e-05
# faite 	officiellement 	8.21490183192e-05
# faits 	maintenant 	8.21490183192e-05
# faits 	prêtons 	8.21490183192e-05
# fallait 	arrêter 	8.21490183192e-05
# fallait 	fournir 	8.21490183192e-05
# fallait 	évaluer 	8.21490183192e-05
# fallu 	faire 	8.21490183192e-05
# fallut 	soustraire 	8.21490183192e-05
# famille 	spirituelle 	8.21490183192e-05
# familles 	fort 	8.21490183192e-05
# familles 	guadeloupe 	8.21490183192e-05
# familles 	latry 	8.21490183192e-05
# familles 	rihes 	8.21490183192e-05
# familles 	victimes 	8.21490183192e-05
# fanatiquement 	dévouée 	8.21490183192e-05
# fassent 	tomber 	8.21490183192e-05
# fatal 	événement 	8.21490183192e-05
# fatalité 	faisait 	8.21490183192e-05
# fatalité 	trouvant 	8.21490183192e-05
# fauche 	disons 	8.21490183192e-05
# fausses 	accusations 	8.21490183192e-05
# fausses 	alertes 	8.21490183192e-05
# faut 	messieurs 	8.21490183192e-05
# faut 	taire 	8.21490183192e-05
# fautes 	commises 	8.21490183192e-05
# favete 	linguis 	8.21490183192e-05
# faveurs 	populaires 	8.21490183192e-05
# femmes 	voulaient 	8.21490183192e-05
# fer 	garde 	8.21490183192e-05
# fermelé 	peut 	8.21490183192e-05
# fernand 	usinier 	8.21490183192e-05
# feu 	gagnait 	8.21490183192e-05
# feu 	pût 	8.21490183192e-05
# feu 	sacré 	8.21490183192e-05
# feu 	théâtre 	8.21490183192e-05
# feuille 	savent 	8.21490183192e-05
# feuillet 	muncipal 	8.21490183192e-05
# fiel 	peut 	8.21490183192e-05
# fils 	alué 	8.21490183192e-05
# fit 	sauter 	8.21490183192e-05
# flambait 	come 	8.21490183192e-05
# flamme 	attisée 	8.21490183192e-05
# flamme 	divine 	8.21490183192e-05
# flamme 	viendrait 	8.21490183192e-05
# flammes 	adoremus 	8.21490183192e-05
# flammes 	grâce 	8.21490183192e-05
# flammes 	mêlés 	8.21490183192e-05
# fléau 	consommer 	8.21490183192e-05
# foi 	traversaient 	8.21490183192e-05
# fois 	rappeler 	8.21490183192e-05
# fois 	ruinées 	8.21490183192e-05
# foncier 	colonial 	8.21490183192e-05
# font 	cmme 	8.21490183192e-05
# fontque 	resserrer 	8.21490183192e-05
# fort 	cher 	8.21490183192e-05
# fort 	duquesnay 	8.21490183192e-05
# fort 	tartenson 	8.21490183192e-05
# forte 	raison 	8.21490183192e-05
# fortes 	rafales 	8.21490183192e-05
# foule 	activement 	8.21490183192e-05
# fourmillière 	innombrable 	8.21490183192e-05
# foyer 	originaire 	8.21490183192e-05
# francs 	don 	8.21490183192e-05
# francs 	déposée 	8.21490183192e-05
# francs 	mis 	8.21490183192e-05
# francs 	mise 	8.21490183192e-05
# francs 	monsieur 	8.21490183192e-05
# francs 	placés 	8.21490183192e-05
# francs 	votés 	8.21490183192e-05
# français 	livres 	8.21490183192e-05
# fruits 	amassés 	8.21490183192e-05
# fruits 	résultera 	8.21490183192e-05
# frères 	habitants 	8.21490183192e-05
# frères 	tendres 	8.21490183192e-05
# fumée 	sortir 	8.21490183192e-05
# février 	août 	8.21490183192e-05
# gai 	soleil 	8.21490183192e-05
# galland 	général 	8.21490183192e-05
# gant 	nou 	8.21490183192e-05
# gendarmes 	dits 	8.21490183192e-05
# gendarmes 	parcourent 	8.21490183192e-05
# gerard 	masson 	8.21490183192e-05
# gerbe 	fauche 	8.21490183192e-05
# gouerement 	avisant 	8.21490183192e-05
# gouffre 	insondable 	8.21490183192e-05
# gouffres 	insondables 	8.21490183192e-05
# goutte 	amère 	8.21490183192e-05
# gouvernement 	ainsi 	8.21490183192e-05
# gouvernement 	métropolitain 	8.21490183192e-05
# gouvernement 	éprouve 	8.21490183192e-05
# gouverneur 	attaqué 	8.21490183192e-05
# gouverneur 	chambres 	8.21490183192e-05
# gouverneur 	métropolitain 	8.21490183192e-05
# gouvernur 	dit 	8.21490183192e-05
# gracieusement 	mis 	8.21490183192e-05
# graciusement 	proposé 	8.21490183192e-05
# grand 	dieu 	8.21490183192e-05
# grande 	loterie 	8.21490183192e-05
# grande 	partie 	8.21490183192e-05
# grande 	quantité 	8.21490183192e-05
# grande 	utilité 	8.21490183192e-05
# grande 	valeur 	8.21490183192e-05
# grandeur 	ouverte 	8.21490183192e-05
# grands 	boulevards 	8.21490183192e-05
# granger 	juge 	8.21490183192e-05
# grossissante 	trainant 	8.21490183192e-05
# guadeloupe 	mentionne 	8.21490183192e-05
# guadeloupe 	merci 	8.21490183192e-05
# guadeloupe 	tiendra 	8.21490183192e-05
# guillaume 	évêque 	8.21490183192e-05
# gémissements 	tant 	8.21490183192e-05
# génie 	fasciner 	8.21490183192e-05
# généreuse 	attention 	8.21490183192e-05
# généreuse 	conduite 	8.21490183192e-05
# généreux 	dévouement 	8.21490183192e-05
# généreux 	écho 	8.21490183192e-05
# générosité 	artistes 	8.21490183192e-05
# générosité 	publique 	8.21490183192e-05
# habitants 	là 	8.21490183192e-05
# habitants 	maire 	8.21490183192e-05
# harmonies 	fassent 	8.21490183192e-05
# harmonieux 	instruments 	8.21490183192e-05
# haut 	pauvre 	8.21490183192e-05
# haut 	témoignage 	8.21490183192e-05
# haute 	mission 	8.21490183192e-05
# hayot 	octave 	8.21490183192e-05
# henri 	avocat 	8.21490183192e-05
# hier 	juillet 	8.21490183192e-05
# hier 	juin 	8.21490183192e-05
# hier 	soir 	8.21490183192e-05
# homme 	expérimenté 	8.21490183192e-05
# honorables 	négociants 	8.21490183192e-05
# horriblement 	surveillance 	8.21490183192e-05
# humains 	informes 	8.21490183192e-05
# hélas 	fasse 	8.21490183192e-05
# hélas 	supérieur 	8.21490183192e-05
# idem 	clerc 	8.21490183192e-05
# idem 	lalung 	8.21490183192e-05
# idet 	joyau 	8.21490183192e-05
# illusion 	profonde 	8.21490183192e-05
# illégalement 	agi 	8.21490183192e-05
# illégalités 	pullulant 	8.21490183192e-05
# immense 	brasier 	8.21490183192e-05
# immigration 	ecoles 	8.21490183192e-05
# immédiatement 	installée 	8.21490183192e-05
# in 	rendu 	8.21490183192e-05
# in 	œternum 	8.21490183192e-05
# incendie 	complètement 	8.21490183192e-05
# incendie 	violence 	8.21490183192e-05
# indications 	nécessaires 	8.21490183192e-05
# indienne 	servante 	8.21490183192e-05
# individus 	chargés 	8.21490183192e-05
# individus 	regardaient 	8.21490183192e-05
# inexprimable 	calamité 	8.21490183192e-05
# informes 	noircis 	8.21490183192e-05
# infortunées 	victimes 	8.21490183192e-05
# infortunés 	compatriotes 	8.21490183192e-05
# infortunés 	tant 	8.21490183192e-05
# iniquité 	inconscient 	8.21490183192e-05
# iniquités 	oui 	8.21490183192e-05
# innombrable 	humains 	8.21490183192e-05
# inouïe 	déclarait 	8.21490183192e-05
# insondable 	créé 	8.21490183192e-05
# instruments 	retenir 	8.21490183192e-05
# inventions 	malveillantes 	8.21490183192e-05
# investigation 	minutieuse 	8.21490183192e-05
# involontaires 	nousle 	8.21490183192e-05
# irréparables 	monsieur 	8.21490183192e-05
# jadis 	foyer 	8.21490183192e-05
# jetons 	plutôt 	8.21490183192e-05
# jetée 	partout 	8.21490183192e-05
# jeudi 	juillet 	8.21490183192e-05
# jeun 	dévorés 	8.21490183192e-05
# jeune 	indienne 	8.21490183192e-05
# joseph 	alexandre 	8.21490183192e-05
# journal 	rapporte 	8.21490183192e-05
# journaliste 	dávoir 	8.21490183192e-05
# jours 	suivants 	8.21490183192e-05
# joyau 	jules 	8.21490183192e-05
# juillet 	courant 	8.21490183192e-05
# juillet 	fête 	8.21490183192e-05
# juillet 	placard 	8.21490183192e-05
# juillet 	vive 	8.21490183192e-05
# juilliet 	ainsi 	8.21490183192e-05
# juin 	asselin 	8.21490183192e-05
# juin 	heuers 	8.21490183192e-05
# juin 	martinique 	8.21490183192e-05
# juin 	réunie 	8.21490183192e-05
# jules 	ancien 	8.21490183192e-05
# justement 	chère 	8.21490183192e-05
# justement 	flatteuse 	8.21490183192e-05
# jésus 	christ 	8.21490183192e-05
# laissant 	tromper 	8.21490183192e-05
# laisse 	entendre 	8.21490183192e-05
# laisse 	pénétrer 	8.21490183192e-05
# laisser 	fléau 	8.21490183192e-05
# laissé 	aller 	8.21490183192e-05
# lalung 	cie 	8.21490183192e-05
# lalung 	idem 	8.21490183192e-05
# lalung 	vient 	8.21490183192e-05
# lamentable 	fatalité 	8.21490183192e-05
# lamentable 	surtout 	8.21490183192e-05
# lamentation 	biblique 	8.21490183192e-05
# lapeyre 	conseiller 	8.21490183192e-05
# large 	mesure 	8.21490183192e-05
# larmes 	douleur 	8.21490183192e-05
# latry 	roby 	8.21490183192e-05
# latérale 	subsistent 	8.21490183192e-05
# lavigne 	beaucoup 	8.21490183192e-05
# lesdroits 	sentiments 	8.21490183192e-05
# lettres 	providentiellement 	8.21490183192e-05
# libres 	généreuses 	8.21490183192e-05
# lieu 	tant 	8.21490183192e-05
# lieu 	vaste 	8.21490183192e-05
# lieu 	vivant 	8.21490183192e-05
# ligne 	partant 	8.21490183192e-05
# ligne 	équatoriale 	8.21490183192e-05
# linge 	argent 	8.21490183192e-05
# linguis 	hier 	8.21490183192e-05
# listes 	précédentes 	8.21490183192e-05
# livre 	funéraire 	8.21490183192e-05
# loi 	presque 	8.21490183192e-05
# long 	cri 	8.21490183192e-05
# longtemps 	flambait 	8.21490183192e-05
# longtemps 	hélas 	8.21490183192e-05
# longtemps 	récentes 	8.21490183192e-05
# longues 	années 	8.21490183192e-05
# loterie 	va 	8.21490183192e-05
# loueront 	secrètement 	8.21490183192e-05
# lourde 	responsabilité 	8.21490183192e-05
# lourdes 	responsabilités 	8.21490183192e-05
# ls 	fronts 	8.21490183192e-05
# ls 	sos 	8.21490183192e-05
# lu 	ailleurs 	8.21490183192e-05
# lugubre 	arrivait 	8.21490183192e-05
# lugubre 	promenade 	8.21490183192e-05
# lundi 	matin 	8.21490183192e-05
# lutte 	acharnée 	8.21490183192e-05
# lutteur 	blessé 	8.21490183192e-05
# là 	aboutir 	8.21490183192e-05
# là 	bon 	8.21490183192e-05
# là 	disséminés 	8.21490183192e-05
# là 	faible 	8.21490183192e-05
# machination 	calculée 	8.21490183192e-05
# machination 	perfide 	8.21490183192e-05
# machine 	surchauffée 	8.21490183192e-05
# magasin 	séguin 	8.21490183192e-05
# magnifique 	hospice 	8.21490183192e-05
# main 	impuissante 	8.21490183192e-05
# main 	invisible 	8.21490183192e-05
# mains 	suppliantes 	8.21490183192e-05
# maintenant 	fallait 	8.21490183192e-05
# maintenant 	puissent 	8.21490183192e-05
# maire 	demonsieur 	8.21490183192e-05
# maire 	prend 	8.21490183192e-05
# maison 	audemar 	8.21490183192e-05
# maison 	borde 	8.21490183192e-05
# maison 	querhoent 	8.21490183192e-05
# maison 	straus 	8.21490183192e-05
# maisons 	amies 	8.21490183192e-05
# maisons 	francs 	8.21490183192e-05
# malade 	affaissé 	8.21490183192e-05
# malheur 	abattu 	8.21490183192e-05
# malheur 	doit 	8.21490183192e-05
# malheur 	habitants 	8.21490183192e-05
# malheur 	incendie 	8.21490183192e-05
# malheur 	pût 	8.21490183192e-05
# malheur 	sait 	8.21490183192e-05
# malheureuses 	secondé 	8.21490183192e-05
# malheureux 	colonie 	8.21490183192e-05
# malheureux 	compatriotes 	8.21490183192e-05
# malheureux 	consigné 	8.21490183192e-05
# malheureux 	incendies 	8.21490183192e-05
# mandemant 	episcopal 	8.21490183192e-05
# manifestations 	charité 	8.21490183192e-05
# manière 	expresse 	8.21490183192e-05
# manière 	générale 	8.21490183192e-05
# manière 	moniteur 	8.21490183192e-05
# marché 	nouvel 	8.21490183192e-05
# mardi 	juillet 	8.21490183192e-05
# marine 	roussel 	8.21490183192e-05
# martinique 	accorde 	8.21490183192e-05
# martinique 	avc 	8.21490183192e-05
# martinique 	convoquait 	8.21490183192e-05
# martinique 	unanimement 	8.21490183192e-05
# martinique 	vu 	8.21490183192e-05
# martiniquepar 	mandement 	8.21490183192e-05
# masse 	noirâtre 	8.21490183192e-05
# matériaux 	provenant 	8.21490183192e-05
# mauvais 	plaisant 	8.21490183192e-05
# mauvais 	tenir 	8.21490183192e-05
# maux 	peccata 	8.21490183192e-05
# menaces 	suivantes 	8.21490183192e-05
# menacé 	semblait 	8.21490183192e-05
# mentionne 	partie 	8.21490183192e-05
# mer 	passant 	8.21490183192e-05
# mercredi 	dernie 	8.21490183192e-05
# mesure 	nécessaire 	8.21490183192e-05
# mesure 	pénible 	8.21490183192e-05
# mesures 	prises 	8.21490183192e-05
# mesures 	sages 	8.21490183192e-05
# mettre 	volontairement 	8.21490183192e-05
# mieux 	défendu 	8.21490183192e-05
# mieux 	exprimée 	8.21490183192e-05
# mieux 	résumée 	8.21490183192e-05
# milions 	faudrait 	8.21490183192e-05
# miraculeux 	pareille 	8.21490183192e-05
# mis 	largement 	8.21490183192e-05
# misère 	courbe 	8.21490183192e-05
# misère 	durera 	8.21490183192e-05
# misères 	innombrables 	8.21490183192e-05
# moindre 	aggravation 	8.21490183192e-05
# moindre 	expression 	8.21490183192e-05
# moindre 	malheur 	8.21490183192e-05
# mois 	quête 	8.21490183192e-05
# moitié 	calcinées 	8.21490183192e-05
# moment 	abrités 	8.21490183192e-05
# moment 	faussées 	8.21490183192e-05
# monde 	hommes 	8.21490183192e-05
# moniteur 	publie 	8.21490183192e-05
# monseigneur 	carmené 	8.21490183192e-05
# monseigneur 	pourrait 	8.21490183192e-05
# monseigneur 	riou 	8.21490183192e-05
# monseigneur 	écrira 	8.21490183192e-05
# monseiur 	riou 	8.21490183192e-05
# monsieur 	bédiat 	8.21490183192e-05
# monsieur 	duquesnay 	8.21490183192e-05
# monsieur 	eustache 	8.21490183192e-05
# monsieur 	girard 	8.21490183192e-05
# montre 	plein 	8.21490183192e-05
# montré 	impitoyable 	8.21490183192e-05
# montrés 	frères 	8.21490183192e-05
# moralement 	dela 	8.21490183192e-05
# morne 	stupeur 	8.21490183192e-05
# morts 	occasionnées 	8.21490183192e-05
# mot 	échappées 	8.21490183192e-05
# mots 	adoremus 	8.21490183192e-05
# mots 	placés 	8.21490183192e-05
# moyens 	soutenu 	8.21490183192e-05
# msures 	secourables 	8.21490183192e-05
# municipalité 	lieu 	8.21490183192e-05
# murs 	attristés 	8.21490183192e-05
# murs 	brisés 	8.21490183192e-05
# murs 	ville 	8.21490183192e-05
# mutuelle 	réellement 	8.21490183192e-05
# mère 	paris 	8.21490183192e-05
# mère 	patrie 	8.21490183192e-05
# méfaits 	déclarer 	8.21490183192e-05
# méritante 	occasion 	8.21490183192e-05
# métropole 	avertie 	8.21490183192e-05
# métropole 	manière 	8.21490183192e-05
# métropolitain 	désarmé 	8.21490183192e-05
# narguaient 	dieu 	8.21490183192e-05
# nature 	superlativement 	8.21490183192e-05
# navire 	viet 	8.21490183192e-05
# nese 	possédera 	8.21490183192e-05
# nicole 	conseillers 	8.21490183192e-05
# nid 	ravagé 	8.21490183192e-05
# noble 	vieillard 	8.21490183192e-05
# noircis 	carbonisés 	8.21490183192e-05
# noire 	misère 	8.21490183192e-05
# noirs 	projets 	8.21490183192e-05
# noirâtre 	informe 	8.21490183192e-05
# nombre 	considérable 	8.21490183192e-05
# nombreuses 	familles 	8.21490183192e-05
# nombreuses 	patrouilles 	8.21490183192e-05
# nombreuses 	trop 	8.21490183192e-05
# nombreux 	secours 	8.21490183192e-05
# nommé 	ensuite 	8.21490183192e-05
# nore 	feuille 	8.21490183192e-05
# nostra 	responderunt 	8.21490183192e-05
# note 	devient 	8.21490183192e-05
# nousle 	supposons 	8.21490183192e-05
# nouveau 	réunie 	8.21490183192e-05
# nouvel 	ordre 	8.21490183192e-05
# nouvelle 	liste 	8.21490183192e-05
# nouvelle 	mairie 	8.21490183192e-05
# nouvelles 	familles 	8.21490183192e-05
# nouvelles 	remises 	8.21490183192e-05
# nuit 	favorisé 	8.21490183192e-05
# nuit 	trop 	8.21490183192e-05
# nécessitait 	tant 	8.21490183192e-05
# négociants 	denotre 	8.21490183192e-05
# nôtres 	juin 	8.21490183192e-05
# obtenir 	piétinneraient 	8.21490183192e-05
# occasionnées 	parle 	8.21490183192e-05
# occupation 	militaire 	8.21490183192e-05
# octave 	idem 	8.21490183192e-05
# offrent 	guère 	8.21490183192e-05
# olméta 	idet 	8.21490183192e-05
# omnibus 	debitor 	8.21490183192e-05
# onit 	étonnés 	8.21490183192e-05
# opinion 	seul 	8.21490183192e-05
# opuentes 	heureuses 	8.21490183192e-05
# opulente 	cité 	8.21490183192e-05
# ornementations 	splendide 	8.21490183192e-05
# os 	larmes 	8.21490183192e-05
# osons 	dire 	8.21490183192e-05
# oui 	expéditif 	8.21490183192e-05
# our 	francs 	8.21490183192e-05
# our 	prier 	8.21490183192e-05
# outrage 	ainsi 	8.21490183192e-05
# ouvrez 	crédit 	8.21490183192e-05
# palir 	voir 	8.21490183192e-05
# paquets 	crevant 	8.21490183192e-05
# paraît 	disposé 	8.21490183192e-05
# pareil 	désastre 	8.21490183192e-05
# pareille 	occurence 	8.21490183192e-05
# pareille 	somme 	8.21490183192e-05
# pareille 	tôt 	8.21490183192e-05
# pareilles 	douleurs 	8.21490183192e-05
# pareils 	maux 	8.21490183192e-05
# parer 	premiers 	8.21490183192e-05
# paril 	cas 	8.21490183192e-05
# parle 	feu 	8.21490183192e-05
# parlement 	paraît 	8.21490183192e-05
# parlé 	beaucoup 	8.21490183192e-05
# parole 	comment 	8.21490183192e-05
# paroles 	blasphématoires 	8.21490183192e-05
# paroles 	faut 	8.21490183192e-05
# paroles 	formuler 	8.21490183192e-05
# paroles 	messieurs 	8.21490183192e-05
# part 	onit 	8.21490183192e-05
# part 	quartier 	8.21490183192e-05
# parti 	contraire 	8.21490183192e-05
# parti 	républicain 	8.21490183192e-05
# particulièrement 	douloureux 	8.21490183192e-05
# particulièrement 	éprouvées 	8.21490183192e-05
# parties 	ville 	8.21490183192e-05
# partisans 	dévoués 	8.21490183192e-05
# paru 	dangereux 	8.21490183192e-05
# parvenir 	immédiatement 	8.21490183192e-05
# parvenirleurs 	offrandes 	8.21490183192e-05
# parée 	embellie 	8.21490183192e-05
# passage 	poutre 	8.21490183192e-05
# passe 	généralement 	8.21490183192e-05
# pasteur 	absent 	8.21490183192e-05
# patientos 	espérons 	8.21490183192e-05
# patriote 	peut 	8.21490183192e-05
# patriotique 	devoir 	8.21490183192e-05
# patrouilles 	circulent 	8.21490183192e-05
# pauvre 	pays 	8.21490183192e-05
# pauvre 	population 	8.21490183192e-05
# pauvre 	tabernacle 	8.21490183192e-05
# pauvres 	gens 	8.21490183192e-05
# pay 	sufferers 	8.21490183192e-05
# payer 	fort 	8.21490183192e-05
# pays 	entier 	8.21490183192e-05
# pays 	menacé 	8.21490183192e-05
# paysun 	home 	8.21490183192e-05
# peccata 	nostra 	8.21490183192e-05
# peine 	vêtues 	8.21490183192e-05
# perdu 	place 	8.21490183192e-05
# permis 	obligatoire 	8.21490183192e-05
# pernain 	distingué 	8.21490183192e-05
# perpétuelle 	agitation 	8.21490183192e-05
# personnages 	quenous 	8.21490183192e-05
# personnes 	beaucoup 	8.21490183192e-05
# personnes 	soustrayant 	8.21490183192e-05
# perte 	sèche 	8.21490183192e-05
# pesait 	su 	8.21490183192e-05
# petit 	trou 	8.21490183192e-05
# petite 	enceinte 	8.21490183192e-05
# petits 	batons 	8.21490183192e-05
# petits 	comprennent 	8.21490183192e-05
# peuple 	chrétien 	8.21490183192e-05
# peut 	aller 	8.21490183192e-05
# peut 	comper 	8.21490183192e-05
# peut 	servir 	8.21490183192e-05
# peut 	seule 	8.21490183192e-05
# peuvent 	dormir 	8.21490183192e-05
# pieuvres 	attachées 	8.21490183192e-05
# pitié 	émue 	8.21490183192e-05
# placard 	contenant 	8.21490183192e-05
# place 	bertin 	8.21490183192e-05
# place 	infime 	8.21490183192e-05
# places 	distinctives 	8.21490183192e-05
# placés 	là 	8.21490183192e-05
# plu 	tristes 	8.21490183192e-05
# plusvives 	protestations 	8.21490183192e-05
# poignante 	douleur 	8.21490183192e-05
# point 	dévastée 	8.21490183192e-05
# police 	devrait 	8.21490183192e-05
# police 	enregistrement 	8.21490183192e-05
# politique 	coloniale 	8.21490183192e-05
# pompes 	manquaient 	8.21490183192e-05
# population 	guadeloupe 	8.21490183192e-05
# por 	contenir 	8.21490183192e-05
# porion 	capitaine 	8.21490183192e-05
# porteur 	somme 	8.21490183192e-05
# possible 	construire 	8.21490183192e-05
# possible 	ruinés 	8.21490183192e-05
# pou 	porter 	8.21490183192e-05
# pourra 	apporter 	8.21490183192e-05
# pourra 	combler 	8.21490183192e-05
# pourra 	jeter 	8.21490183192e-05
# pourra 	supporter 	8.21490183192e-05
# pourrons 	répondre 	8.21490183192e-05
# poursuivies 	bientôt 	8.21490183192e-05
# poussée 	trop 	8.21490183192e-05
# pouviez 	prévoir 	8.21490183192e-05
# pouvoir 	juger 	8.21490183192e-05
# pouvoir 	réussir 	8.21490183192e-05
# premier 	bruit 	8.21490183192e-05
# premier 	moment 	8.21490183192e-05
# premiers 	apôtres 	8.21490183192e-05
# premiers 	besoins 	8.21490183192e-05
# premiers 	dons 	8.21490183192e-05
# premiers 	gardiens 	8.21490183192e-05
# premiers 	traits 	8.21490183192e-05
# première 	entrainerait 	8.21490183192e-05
# première 	fois 	8.21490183192e-05
# première 	nouvelle 	8.21490183192e-05
# première 	pompe 	8.21490183192e-05
# première 	somme 	8.21490183192e-05
# premières 	heures 	8.21490183192e-05
# premières 	larmes 	8.21490183192e-05
# premières 	manifestations 	8.21490183192e-05
# prend 	passage 	8.21490183192e-05
# prendre 	immédiatement 	8.21490183192e-05
# prendre 	mesure 	8.21490183192e-05
# prenons 	parfois 	8.21490183192e-05
# prenons 	part 	8.21490183192e-05
# presbytère 	embrasé 	8.21490183192e-05
# presbytère 	immigration 	8.21490183192e-05
# presque 	silentement 	8.21490183192e-05
# presque 	épuisé 	8.21490183192e-05
# presque 	épuisée 	8.21490183192e-05
# principaux 	trop 	8.21490183192e-05
# pris 	mesures 	8.21490183192e-05
# prises 	aussitôt 	8.21490183192e-05
# privé 	duquesnay 	8.21490183192e-05
# privé 	suppléant 	8.21490183192e-05
# pro 	luisirent 	8.21490183192e-05
# prochain 	quêtes 	8.21490183192e-05
# proclamation 	suivante 	8.21490183192e-05
# profondément 	touché 	8.21490183192e-05
# projets 	perfides 	8.21490183192e-05
# promptement 	répondu 	8.21490183192e-05
# propagea 	bientôt 	8.21490183192e-05
# proportions 	indomptables 	8.21490183192e-05
# providentiellement 	épargnées 	8.21490183192e-05
# provoquer 	recueillir 	8.21490183192e-05
# prudence 	veut 	8.21490183192e-05
# prè 	dece 	8.21490183192e-05
# prècha 	faisons 	8.21490183192e-05
# précis 	cablez 	8.21490183192e-05
# précisément 	adoucir 	8.21490183192e-05
# précédentes 	done 	8.21490183192e-05
# prélude 	concert 	8.21490183192e-05
# présente 	décision 	8.21490183192e-05
# prétend 	avoir 	8.21490183192e-05
# pu 	circonscrire 	8.21490183192e-05
# pu 	profiter 	8.21490183192e-05
# pu 	retirer 	8.21490183192e-05
# pu 	servir 	8.21490183192e-05
# public 	honneur 	8.21490183192e-05
# publiés 	donne 	8.21490183192e-05
# puisse 	entendre 	8.21490183192e-05
# puisse 	faire 	8.21490183192e-05
# purent 	valides 	8.21490183192e-05
# pussent 	maintenir 	8.21490183192e-05
# père 	dévoué 	8.21490183192e-05
# pèse 	beaucoup 	8.21490183192e-05
# pénible 	encoer 	8.21490183192e-05
# péril 	expira 	8.21490183192e-05
# périls 	auxqules 	8.21490183192e-05
# pûmes 	contenir 	8.21490183192e-05
# quartier 	dit 	8.21490183192e-05
# quartier 	enquartier 	8.21490183192e-05
# quarts 	détruite 	8.21490183192e-05
# quarts 	environ 	8.21490183192e-05
# quenous 	avonschassés 	8.21490183192e-05
# quleque 	chose 	8.21490183192e-05
# quête 	extraodinaire 	8.21490183192e-05
# rais 	brulé 	8.21490183192e-05
# ramasserons 	ous 	8.21490183192e-05
# rapidement 	camp 	8.21490183192e-05
# receveurs 	municipaux 	8.21490183192e-05
# recevrait 	faible 	8.21490183192e-05
# recueillies 	tant 	8.21490183192e-05
# recueillir 	beaucoup 	8.21490183192e-05
# regarde 	œil 	8.21490183192e-05
# regards 	donnez 	8.21490183192e-05
# regrettables 	croyons 	8.21490183192e-05
# regretter 	ellesne 	8.21490183192e-05
# releva 	jadis 	8.21490183192e-05
# relever 	tant 	8.21490183192e-05
# relief 	poignante 	8.21490183192e-05
# remecier 	personnellement 	8.21490183192e-05
# remiers 	modèles 	8.21490183192e-05
# rend 	compte 	8.21490183192e-05
# rendaient 	coupables 	8.21490183192e-05
# rendre 	déjàpénitente 	8.21490183192e-05
# rendre 	visite 	8.21490183192e-05
# rendu 	hier 	8.21490183192e-05
# rendu 	mercredi 	8.21490183192e-05
# renseignements 	détaillés 	8.21490183192e-05
# renseignements 	précis 	8.21490183192e-05
# représente 	germain 	8.21490183192e-05
# ressemblenet 	singulièrement 	8.21490183192e-05
# restes 	corps 	8.21490183192e-05
# retenir 	attirez 	8.21490183192e-05
# revinrent 	annonçant 	8.21490183192e-05
# reçu 	trop 	8.21490183192e-05
# rich 	parée 	8.21490183192e-05
# rihes 	opuentes 	8.21490183192e-05
# rinidad 	det 	8.21490183192e-05
# riz 	autant 	8.21490183192e-05
# roby 	déclèmy 	8.21490183192e-05
# roussel 	colonial 	8.21490183192e-05
# roy 	eustache 	8.21490183192e-05
# rubrique 	souscriptions 	8.21490183192e-05
# rude 	terrible 	8.21490183192e-05
# rue 	blénac 	8.21490183192e-05
# rue 	brulé 	8.21490183192e-05
# rue 	déviant 	8.21490183192e-05
# rue 	perrinon 	8.21490183192e-05
# rues 	blénac 	8.21490183192e-05
# ruines 	accumulées 	8.21490183192e-05
# ruines 	brûlantes 	8.21490183192e-05
# ruines 	dit 	8.21490183192e-05
# ruines 	décombres 	8.21490183192e-05
# règle 	générale 	8.21490183192e-05
# récemment 	parus 	8.21490183192e-05
# récent 	incendie 	8.21490183192e-05
# récentes 	processions 	8.21490183192e-05
# réception 	renseignements 	8.21490183192e-05
# rédaction 	échangeant 	8.21490183192e-05
# réellement 	avecrage 	8.21490183192e-05
# réfugier 	ailleurs 	8.21490183192e-05
# réprobation 	publique 	8.21490183192e-05
# résolutions 	nobles 	8.21490183192e-05
# réunion 	publique 	8.21490183192e-05
# réunira 	également 	8.21490183192e-05
# saane 	transformée 	8.21490183192e-05
# sachent 	faire 	8.21490183192e-05
# sacs 	riz 	8.21490183192e-05
# sage 	liberté 	8.21490183192e-05
# saint 	guillaume 	8.21490183192e-05
# saisissement 	dernière 	8.21490183192e-05
# sait 	citoyens 	8.21490183192e-05
# sait 	comment 	8.21490183192e-05
# sait 	existela 	8.21490183192e-05
# sas 	compromettre 	8.21490183192e-05
# saurait 	définir 	8.21490183192e-05
# saurait 	intervenir 	8.21490183192e-05
# saurait 	précisément 	8.21490183192e-05
# saurait 	étrange 	8.21490183192e-05
# saurions 	dire 	8.21490183192e-05
# savane 	montant 	8.21490183192e-05
# savants 	donnez 	8.21490183192e-05
# scandaleuse 	division 	8.21490183192e-05
# science 	artistes 	8.21490183192e-05
# scène 	coloniale 	8.21490183192e-05
# second 	bateau 	8.21490183192e-05
# second 	dún 	8.21490183192e-05
# second 	refuge 	8.21490183192e-05
# seconde 	fois 	8.21490183192e-05
# seconde 	liste 	8.21490183192e-05
# secondée 	ar 	8.21490183192e-05
# secourables 	prises 	8.21490183192e-05
# secourir 	pourra 	8.21490183192e-05
# secours 	arrivent 	8.21490183192e-05
# secours 	monsieur 	8.21490183192e-05
# secours 	ouvrez 	8.21490183192e-05
# secours 	vinrent 	8.21490183192e-05
# secours 	vont 	8.21490183192e-05
# secours 	votés 	8.21490183192e-05
# secouru 	spontanément 	8.21490183192e-05
# secret 	bonheur 	8.21490183192e-05
# semblables 	insensible 	8.21490183192e-05
# semblait 	souffler 	8.21490183192e-05
# senties 	doivent 	8.21490183192e-05
# sentiment 	presque 	8.21490183192e-05
# sentiments 	charitables 	8.21490183192e-05
# sentiments 	magnanimes 	8.21490183192e-05
# sentiments 	nousverrons 	8.21490183192e-05
# sentiments 	religieux 	8.21490183192e-05
# sentions 	vraiment 	8.21490183192e-05
# servante 	cehz 	8.21490183192e-05
# servir 	gouverneur 	8.21490183192e-05
# seul 	coup 	8.21490183192e-05
# seul 	instant 	8.21490183192e-05
# seul 	langage 	8.21490183192e-05
# seul 	point 	8.21490183192e-05
# seul 	vouloir 	8.21490183192e-05
# seule 	flèche 	8.21490183192e-05
# seule 	parole 	8.21490183192e-05
# seule 	reste 	8.21490183192e-05
# seule 	réagir 	8.21490183192e-05
# seulement 	peut 	8.21490183192e-05
# simple 	entrefilet 	8.21490183192e-05
# simple 	humanité 	8.21490183192e-05
# simple 	idée 	8.21490183192e-05
# simple 	récit 	8.21490183192e-05
# simplement 	acte 	8.21490183192e-05
# simplement 	héroïques 	8.21490183192e-05
# simplement 	sensible 	8.21490183192e-05
# simples 	mots 	8.21490183192e-05
# sinistre 	journée 	8.21490183192e-05
# situation 	actuelle 	8.21490183192e-05
# situation 	anormale 	8.21490183192e-05
# situation 	matérielle 	8.21490183192e-05
# siège 	occupation 	8.21490183192e-05
# soir 	incendie 	8.21490183192e-05
# soir 	juilliet 	8.21490183192e-05
# soirée 	musicale 	8.21490183192e-05
# sol 	tremblait 	8.21490183192e-05
# soleil 	ardent 	8.21490183192e-05
# solidariser 	davantage 	8.21490183192e-05
# solide 	prospérité 	8.21490183192e-05
# sontla 	cause 	8.21490183192e-05
# sort 	allait 	8.21490183192e-05
# sortaient 	parfois 	8.21490183192e-05
# sorte 	engloutie 	8.21490183192e-05
# sorte 	rassemblée
# 8.21490183192e-05
# sortede 	canonade 	8.21490183192e-05
# souffert 	étonnamment 	8.21490183192e-05
# souffler 	exprès 	8.21490183192e-05
# souscription 	circulent 	8.21490183192e-05
# souscription 	faite 	8.21490183192e-05
# souscription 	formée 	8.21490183192e-05
# souscription 	spéciale 	8.21490183192e-05
# souscriptions 	diocésaines 	8.21490183192e-05
# souscriptions 	don 	8.21490183192e-05
# souscriptions 	publié 	8.21490183192e-05
# soutiendra 	dernières 	8.21490183192e-05
# souvenance 	haineuse 	8.21490183192e-05
# spacieux 	por 	8.21490183192e-05
# spectacle 	horrible 	8.21490183192e-05
# steamer 	energique 	8.21490183192e-05
# straus 	cie 	8.21490183192e-05
# sufferers 	crumble 	8.21490183192e-05
# suivant 	gouvernement 	8.21490183192e-05
# suivant 	ordinaire 	8.21490183192e-05
# suivant 	télégramme 	8.21490183192e-05
# suivante 	pay 	8.21490183192e-05
# superlativement 	ombrageuse 	8.21490183192e-05
# suprême 	désolation 	8.21490183192e-05
# surcrière 	part 	8.21490183192e-05
# surout 	aggraver 	8.21490183192e-05
# surveillance 	militaire 	8.21490183192e-05
# sèche 	subie 	8.21490183192e-05
# séguin 	négociant 	8.21490183192e-05
# séjour 	vivant 	8.21490183192e-05
# sœur 	voisine 	8.21490183192e-05
# tabernacle 	échappée 	8.21490183192e-05
# tableau 	suivant 	8.21490183192e-05
# tant 	besoin 	8.21490183192e-05
# tant 	fièvreuse 	8.21490183192e-05
# tant 	matériel 	8.21490183192e-05
# tant 	pis 	8.21490183192e-05
# tellement 	rapide 	8.21490183192e-05
# temple 	auparavant 	8.21490183192e-05
# temple 	provisoire 	8.21490183192e-05
# temps 	avoir 	8.21490183192e-05
# temps 	exceptionnel 	8.21490183192e-05
# temps 	orageux 	8.21490183192e-05
# temps 	sereine 	8.21490183192e-05
# tempête 	fouillant 	8.21490183192e-05
# tenir 	compte 	8.21490183192e-05
# tenons 	á 	8.21490183192e-05
# terrain 	meilleur 	8.21490183192e-05
# terrible 	incendie 	8.21490183192e-05
# terribles 	effets 	8.21490183192e-05
# teu 	compte 	8.21490183192e-05
# tirage 	supplementaire 	8.21490183192e-05
# tombeau 	gouffre 	8.21490183192e-05
# trait 	particulièrement 	8.21490183192e-05
# transatlantique 	beillouir 	8.21490183192e-05
# trante 	juin 	8.21490183192e-05
# travailla 	énergiquement 	8.21490183192e-05
# trises 	personnages 	8.21490183192e-05
# triste 	scène 	8.21490183192e-05
# tristes 	gémissements 	8.21490183192e-05
# tristes 	rêves 	8.21490183192e-05
# troise 	heures 	8.21490183192e-05
# troisième 	point 	8.21490183192e-05
# trop 	douloureuse 	8.21490183192e-05
# trop 	nombreuses 	8.21490183192e-05
# trop 	nuit 	8.21490183192e-05
# trop 	plein 	8.21490183192e-05
# trop 	plutôt 	8.21490183192e-05
# trou 	relativement 	8.21490183192e-05
# troupe 	grossissante 	8.21490183192e-05
# troupe 	soldats 	8.21490183192e-05
# troupes 	arrivaient 	8.21490183192e-05
# trouvant 	partout 	8.21490183192e-05
# trouve 	pareil 	8.21490183192e-05
# trouve 	prochainement 	8.21490183192e-05
# trouvera 	là 	8.21490183192e-05
# trouvons 	exposés 	8.21490183192e-05
# trésorier 	payeur 	8.21490183192e-05
# télégramme 	arrivait 	8.21490183192e-05
# télégramme 	donnez 	8.21490183192e-05
# télégrammes 	tant 	8.21490183192e-05
# témoignages 	infatigables 	8.21490183192e-05
# témoin 	digne 	8.21490183192e-05
# tête 	baissée 	8.21490183192e-05
# tête 	séparée 	8.21490183192e-05
# tôt 	possible 	8.21490183192e-05
# unanime 	opinion 	8.21490183192e-05
# unanimement 	patriote 	8.21490183192e-05
# usinier 	hayot 	8.21490183192e-05
# va 	partir 	8.21490183192e-05
# vain 	squelette 	8.21490183192e-05
# valeur 	brulée 	8.21490183192e-05
# vapeu 	va 	8.21490183192e-05
# vapeur 	affrété 	8.21490183192e-05
# vapeur 	partira 	8.21490183192e-05
# vases 	sacrés 	8.21490183192e-05
# vaste 	champ 	8.21490183192e-05
# vaste 	église 	8.21490183192e-05
# vauclin 	convoquée 	8.21490183192e-05
# vendredi 	juillet 	8.21490183192e-05
# vent 	violent 	8.21490183192e-05
# venu 	apporter 	8.21490183192e-05
# venu 	spontanément 	8.21490183192e-05
# verrons 	là 	8.21490183192e-05
# vertes 	pelouses 	8.21490183192e-05
# vertu 	reine 	8.21490183192e-05
# veut 	évidemment 	8.21490183192e-05
# vide 	caveau 	8.21490183192e-05
# vie 	bienheureuse 	8.21490183192e-05
# vieille 	routine 	8.21490183192e-05
# vieilles 	haines 	8.21490183192e-05
# viet 	dire 	8.21490183192e-05
# ville 	assistait 	8.21490183192e-05
# ville 	commerciale 	8.21490183192e-05
# ville 	connaissent 	8.21490183192e-05
# ville 	détruite 	8.21490183192e-05
# ville 	détruites 	8.21490183192e-05
# ville 	famille 	8.21490183192e-05
# ville 	principale 	8.21490183192e-05
# ville 	prè 	8.21490183192e-05
# ville 	sœur 	8.21490183192e-05
# ville 	épiscopale 	8.21490183192e-05
# vindicte 	population 	8.21490183192e-05
# vinrent 	tarder 	8.21490183192e-05
# violence 	inouïe 	8.21490183192e-05
# vite 	portée 	8.21490183192e-05
# vive 	attendrons 	8.21490183192e-05
# vives 	sympathies 	8.21490183192e-05
# vivres 	commission 	8.21490183192e-05
# voient 	également 	8.21490183192e-05
# voir 	offrir 	8.21490183192e-05
# voit 	ruiné 	8.21490183192e-05
# voix 	consultative 	8.21490183192e-05
# volons 	vite 	8.21490183192e-05
# vons 	vu 	8.21490183192e-05
# voulez 	dire 	8.21490183192e-05
# voulons 	entretenir 	8.21490183192e-05
# voulons 	parler 	8.21490183192e-05
# voulu 	accepter 	8.21490183192e-05
# voyageur 	brulé 	8.21490183192e-05
# voyant 	arriver 	8.21490183192e-05
# vrai 	marché 	8.21490183192e-05
# vrai 	rôle 	8.21490183192e-05
# vraiment 	ému 	8.21490183192e-05
# vu 	consterné 	8.21490183192e-05
# vue 	tourner 	8.21490183192e-05
# vérité 	considérables 	8.21490183192e-05
# vérité 	plaisant 	8.21490183192e-05
# xxxi 	parlement 	8.21490183192e-05
# yachts 	embarquèrent 	8.21490183192e-05
# yeux 	grâces 	8.21490183192e-05
# yeux 	pleins 	8.21490183192e-05
# zèle 	infatigable 	8.21490183192e-05
# á 	raconter 	8.21490183192e-05
# âme 	unanime 	8.21490183192e-05
# âmes 	charitables 	8.21490183192e-05
# âmes 	découragées 	8.21490183192e-05
# éait 	facile 	8.21490183192e-05
# éclate 	trouve 	8.21490183192e-05
# économies 	linge 	8.21490183192e-05
# également 	dépouillés 	8.21490183192e-05
# église 	gouverneur 	8.21490183192e-05
# église 	renaîtra 	8.21490183192e-05
# église 	sorte 	8.21490183192e-05
# église 	superbe 	8.21490183192e-05
# égoïste 	dûr 	8.21490183192e-05
# éminent 	supérieur 	8.21490183192e-05
# émotion 	demande 	8.21490183192e-05
# émotions 	reçues 	8.21490183192e-05
# émue 	vivement 	8.21490183192e-05
# énergiquement 	héroïquement 	8.21490183192e-05
# épaix 	nuage 	8.21490183192e-05
# épargné 	merci 	8.21490183192e-05
# épargné 	seigneur 	8.21490183192e-05
# épouvantable 	sinistre 	8.21490183192e-05
# éprouve 	profonde 	8.21490183192e-05
# établissements 	industriels 	8.21490183192e-05
# éteit 	ateinte 	8.21490183192e-05
# étoile 	assis 	8.21490183192e-05
# événement 	occupés 	8.21490183192e-05
# îles 	françaises 	8.21490183192e-05
# œil 	attristé 	8.21490183192e-05
# œuvre 	considérable 	8.21490183192e-05
# œuvre 	destructrice 	8.21490183192e-05

# %%
nltk.Text(all_documents['tokens'],'utf8').concordance("compatriotes",lines=31)
# Out:
# Building index...
# Displaying 19 of 19 matches:
# a machine inventée par un de nos compatriotes qui , paraît-il , se laissait en
# . Et puisque nous parlons de nos compatriotes de Saint-Pierre , citons , comme
#  , la vie , en un mot , pour des compatriotes qui en réclament et en attendent
# ents et la reconnaissance de nos compatriotes ; nous lui en réitérons ici l'ho
# leurant , criant , no malheureux compatriotes du chef-lieu semblaient incapabl
#  d'approvisionner nos malheureux compatriotes du chef-lieu. Dès le lendemain m
# rrivent , s'organisent ; que nos compatriotes de Saint-Pierre , qui se sont mo
# leurant , criant , no malheureux compatriotes du chef-lieu seblaient incapable
#  d'approvisionner nos malheureux compatriotes du chef-lieu. Dès le lendemain m
# rrivent , s'organisent ; que nos compatriotes de Saint-Pierre , qui se sont mo
# lus belle , si possible , où nos compatriotes trouveront les moyens de déploye
# leur imposent à l'égard de leurs compatriotes et frères malheureux. Quel cœur
# césains , pour des frères et des compatriotes malheureux , au Nom du Dieu qui
# us large mesure , nos malheureux compatriotes du chef-lieu.Merci à la Guadelou
# hies vont-elles à nos infortunés compatriotes ; mais nous renonçons à leur exp
# vouloir qui est le bien de leurs compatriotes malheureux.Faisons comme le Maît
# lus belle , si possible , où nos compatriotes trouveront les moyens de déploye
# e vous vindrez au secours de vos compatriotes du Port-Louis.Les souscriptions
# it une douloureuse nouvelle. Nos compatriotes de la Guadeloupe ont été eux aus

# %%
coloniestokens=[]
for document in documents:
    if document['newspaper']=='Les Colonies':
        coloniestokens.extend(document['tokens'])
nltk.Text(coloniestokens,'utf8').concordance("duquesnay",lines=31)
# Out:
# Building index...
# Displaying 31 of 80 matches:
# , lors de l'apparition de feu , M. Duquesnay était absent de Fort-de-France. Il
# lement à constater l'absence de M. Duquesnay , cela parce qu'elle a eu , entend
# l'incendie. Quoiqu'il en soit , M. Duquesnay arriva vers midi , et quand il put
# erait comprise et respectée.M. O , Duquesnay ne l'a pas entendu ainsi. Nous le
# dans la salle , tous amis de M. O. Duquesnay , et c'est le hasard qui y a condu
# rue , y est entré et a vu là M. O. Duquesnay , pérorant comme si de rien n'étai
# ts de la sanglante ironie de M. O. Duquesnay sur ces grosses fortunes disparues
# ation affamée du chef-lieu , M. O. Duquesnay , le maire de cette population , p
# e de la ville de Saint-Pierre ; O. Duquesnay , maire de la ville de Fort-de-Fra
# us dit on , a réuni le 24 juin. M. Duquesnay , maire de Fort-de-France , a été
# s , se produisait , c'est lui , M. Duquesnay , qui serait conduit au fort Dessa
#  serait conduit au fort Dessaix.M. Duquesnay a fait une proclamation où il invi
# , lors de l'apparition de feu , M. Duquesnay était absent de Fort-de-France. Il
# lement à constater l'absence de M. Duquesnay , cela parce qu'elle a eu , entend
# l'incendie. Quoiqu'il en soit , M. Duquesnay arriva vers midi , et quand il put
# e de la ville de Saint-Pierre ; O. Duquesnay , maire de la ville de Fort-de-Fra
# us dit on , a réuni le 24 juin. M. Duquesnay , maire de Fort-de-France , a été
# s , se produisait , c'est lui , M. Duquesnay , qui serait conduit au fort Dessa
#  serait conduit au fort Dessaix.M. Duquesnay a fait une proclamation où il invi
#  de la colonie ; Composée de : MM. Duquesnay , président du conseil général ; C
# t-de-France à la suite de M. Osman Duquesnay , ce roi des ribauds et assistant
# ... , un des amis sans doute de M. Duquesnay , mais un homme intelligent et pat
# ions , et savez-vous comment M. O. Duquesnay , ce bandit , ce saltimbanque , ce
# ermain CasseAprès avoir déclaré M. Duquesnay indigne de la vice-présidence du C
# it point que dans notre colonie M. Duquesnay put jamais arriver à aucun poste p
#  haute intelligence , c'est que M. Duquesnay était un homme néfaste , un homme
# , un homme qui porte malheur.M. O. Duquesnay semble , en effet , voué à une fat
# tigué de politique , un jour M. O. Duquesnay s'avise de demander à M. Hurard d'
# brante et ruineuse personnalité.M. Duquesnay partit à cette époque pour la colo
# tte année même pendant laquelle M. Duquesnay , maire de Fort-de-France , présid
# cendie du chef-lieu. Oh ! oui , M. Duquesnay est un homme néfaste. Il porte mal

# %%
document = documents[1]
for sentence in document['sentences']:
    print sentence, '\n\n'
# Out:
# Fort-de-France n'existe plus !
#
#
# Un terrible incendie l'a complètement détruit.
#
#
# La Guadeloupe tiendra à venir au secours des victimes de cet épouvantable sinistre, avec un empressement égal à celui que la Martinique a montré, en 1871, lors de l'incendie de la Pointe-à-Pitre.
#
#
# Un bâtiment de la compagnie des bateaux à vapeur va partir aujourd'hui pour la Martinique, avec le maire de la Pointe-à-Pitre, pour porter des secours en argent et en nature à nos malheureux compatriotes.
#
#
# La colonie envoie un premier secours de dix mille francs ; la ville de la Pointe-à-Pitre une somme de cinq mille francs.
#
#
# Des listes de souscriptions circulent à la Basse-Terre et dans toutes les communes de la colonie.
#
#
# Il importe que les secours arrivent au plus tôt.
#
#
# Le produit des souscriptions sera versé entre les mains des receveurs municipaux et centralisé au trésor, à la Basse-Terre et à la Ponite-à-Pitre.
#
#
# Le Gouverneur, A.
#
#
# Le Boucher MM.
#
#
# Le Boucher, gouverneur................. 500 00 Feillet, directeur de l'intérieur.......... 100 00 Guy de Ferrières, procureur général........ 100 00 La Barbe, inspecteur des colonies.......... 100 00 Dumothier, chef du service administratif... 50 00 Courcoux, trésorier payeur................. 100 00 Rognon, chef du secrétariat du gouvernement.
#
#
# 25 00 Jolidon, lieutenant détaché................. 25 00 Fougas (Charles), commis du Conseil privé... 5 00 Lefébure (Masséna), écrivain de 1er classe des directions de l'intérieur, détaché au secrétariat du Gouvernement.. 5 00 Total.................................... 1010 00 Le Directeur de l'Intérieur à Messieurs les Maires Monsieur le Maire, Fort-de-France vient d'être complètement incendié.
#
#
# Je fais appel dans cette triste circonstances à votre sentiment de solidarité pour ouvrir immédiatement une souscription dont le montant sera versé à la perception du canton dont votre commune fait partie.
#
#
# Nous ne saurions oublier la spontanéité avec laquelle la colonie sœur, en souffrance aujourd'hui, est venue au secours de la Guadeloupe, lors de l'incendie de la Pointe-à-Pitre, en 1871.
#
#
# Recevez, Monsieur le Maire, l'assurance de ma considération très distinguée.
#
#
# P. Feillet D'après les détails les plus certains obtenus de personnes présentes àl'incendie, à partir du débarcadère, en arrière, justqu'au milieu du côté de l'Ouest de la Savanne, et de là, à la rivière Levasseur, y compris l'usine de la Pointe Simon, tout est détruit.
#
#
# Le feu, qui est occidental, a commencé rue Blénac dans une petite case et s'est étendu de droite et de gauche, avec une rapidité effrayante, vu l'inutilité des pompes, le manque d'eau, les maisons étant contruites en bois, et la force du vent, et a ravagé le long du rivage depuis la Savane jusqu'à la rivière Levasseur.
#
#
# Le Carénage, l'Hôtel du gouvernement, la Direction de l'intérieur, l Hôpital militaire, la Gendarmerie et le Tribunal sont sauvés ; mais tous les autres édifices publics, y compris l'Église, l'Hôtel de ville et la bibliothèque Schœlcher sont complètement détruits.
#
#
# Près de 5,000 personnes sont sans abris et dans le plus grand dénuement, à cause de leur situation en plein air et le manque de nourriture et de vêtements.
#
#
# Jusqu'à présent on a retrouvé cinq cadavres ; beaucoup de personnes sont blessées et il manque cinq soldats.
#
#
# Des secours pour les infortunés sont instamment sollicités.
#
#
# La Savanne est couerte de gens sans abris et manquant de tout.
#
#
# Le feu est sos les cendres maintenant et on ne prévoit aucun danger.
#
#
# A peu près la moitié de la ville est détruite.
#
#
# La ligne télégraphique du Gouvernement était renversée, il n'a pas été possible d'obtenir plus tôt des informations certaines.

# %%
# Out:
# [u"Fort-de-France n'existe plus !", u"Un terrible incendie l'a compl\xe8tement d\xe9truit.", u"La Guadeloupe tiendra \xe0 venir au secours des victimes de cet \xe9pouvantable sinistre, avec un empressement \xe9gal \xe0 celui que la Martinique a montr\xe9, en 1871, lors de l'incendie de la Pointe-\xe0-Pitre.", u"Un b\xe2timent de la compagnie des bateaux \xe0 vapeur va partir aujourd'hui pour la Martinique, avec le maire de la Pointe-\xe0-Pitre, pour porter des secours en argent et en nature \xe0 nos malheureux compatriotes.", u'La colonie envoie un premier secours de dix mille francs ; la ville de la Pointe-\xe0-Pitre une somme de cinq mille francs.', u'Des listes de souscriptions circulent \xe0 la Basse-Terre et dans toutes les communes de la colonie.', u'Il importe que les secours arrivent au plus t\xf4t.', u'Le produit des souscriptions sera vers\xe9 entre les mains des receveurs municipaux et centralis\xe9 au tr\xe9sor, \xe0 la Basse-Terre et \xe0 la Ponite-\xe0-Pitre.', u'Le Gouverneur, A.', u'Le Boucher MM.', u"Le Boucher, gouverneur................. 500 00 Feillet, directeur de l'int\xe9rieur.......... 100 00 Guy de Ferri\xe8res, procureur g\xe9n\xe9ral........ 100 00 La Barbe, inspecteur des colonies.......... 100 00 Dumothier, chef du service administratif... 50 00 Courcoux, tr\xe9sorier payeur................. 100 00 Rognon, chef du secr\xe9tariat du gouvernement.", u"25 00 Jolidon, lieutenant d\xe9tach\xe9................. 25 00 Fougas (Charles), commis du Conseil priv\xe9... 5 00 Lef\xe9bure (Mass\xe9na), \xe9crivain de 1er classe des directions de l'int\xe9rieur, d\xe9tach\xe9 au secr\xe9tariat du Gouvernement.. 5 00 Total.................................... 1010 00 Le Directeur de l'Int\xe9rieur \xe0 Messieurs les Maires Monsieur le Maire, Fort-de-France vient d'\xeatre compl\xe8tement incendi\xe9.", u'Je fais appel dans cette triste circonstances \xe0 votre sentiment de solidarit\xe9 pour ouvrir imm\xe9diatement une souscription dont le montant sera vers\xe9 \xe0 la perception du canton dont votre commune fait partie.', u"Nous ne saurions oublier la spontan\xe9it\xe9 avec laquelle la colonie s\u0153ur, en souffrance aujourd'hui, est venue au secours de la Guadeloupe, lors de l'incendie de la Pointe-\xe0-Pitre, en 1871.", u"Recevez, Monsieur le Maire, l'assurance de ma consid\xe9ration tr\xe8s distingu\xe9e.", u"P. Feillet D'apr\xe8s les d\xe9tails les plus certains obtenus de personnes pr\xe9sentes \xe0l'incendie, \xe0 partir du d\xe9barcad\xe8re, en arri\xe8re, justqu'au milieu du c\xf4t\xe9 de l'Ouest de la Savanne, et de l\xe0, \xe0 la rivi\xe8re Levasseur, y compris l'usine de la Pointe Simon, tout est d\xe9truit.", u"Le feu, qui est occidental, a commenc\xe9 rue Bl\xe9nac dans une petite case et s'est \xe9tendu de droite et de gauche, avec une rapidit\xe9 effrayante, vu l'inutilit\xe9 des pompes, le manque d'eau, les maisons \xe9tant contruites en bois, et la force du vent, et a ravag\xe9 le long du rivage depuis la Savane jusqu'\xe0 la rivi\xe8re Levasseur.", u"Le Car\xe9nage, l'H\xf4tel du gouvernement, la Direction de l'int\xe9rieur, l H\xf4pital militaire, la Gendarmerie et le Tribunal sont sauv\xe9s ; mais tous les autres \xe9difices publics, y compris l'\xc9glise, l'H\xf4tel de ville et la biblioth\xe8que Sch\u0153lcher sont compl\xe8tement d\xe9truits.", u'Pr\xe8s de 5,000 personnes sont sans abris et dans le plus grand d\xe9nuement, \xe0 cause de leur situation en plein air et le manque de nourriture et de v\xeatements.', u"Jusqu'\xe0 pr\xe9sent on a retrouv\xe9 cinq cadavres ; beaucoup de personnes sont bless\xe9es et il manque cinq soldats.", u'Des secours pour les infortun\xe9s sont instamment sollicit\xe9s.', u'La Savanne est couerte de gens sans abris et manquant de tout.', u'Le feu est sos les cendres maintenant et on ne pr\xe9voit aucun danger.', u'A peu pr\xe8s la moiti\xe9 de la ville est d\xe9truite.', u"La ligne t\xe9l\xe9graphique du Gouvernement \xe9tait renvers\xe9e, il n'a pas \xe9t\x ...
